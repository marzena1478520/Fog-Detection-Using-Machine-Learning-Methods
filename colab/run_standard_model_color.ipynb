# %% [markdown]
# # Ray Tune

# %%
# !pip install -U "ray[tune]"
# Out:
# Collecting ray[tune]
#   Downloading ray-2.46.0-cp311-cp311-manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (8.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (3.18.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (4.24.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (1.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (24.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (5.29.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (2.2.2)
# Collecting tensorboardX>=1.9 (from ray[tune])
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pyarrow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (18.1.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (2025.3.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from tensorboardX>=1.9->ray[tune]) (2.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray[tune]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray[tune]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray[tune]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray[tune]) (0.25.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->ray[tune]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->ray[tune]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->ray[tune]) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->ray[tune]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->ray[tune]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->ray[tune]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->ray[tune]) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->ray[tune]) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from referencing>=0.28.4->jsonschema->ray[tune]) (4.14.0)
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 2.4 MB/s eta 0:00:00
# Downloading ray-2.46.0-cp311-cp311-manylinux2014_x86_64.whl (68.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 MB 39.6 MB/s eta 0:00:00
# Installing collected packages: tensorboardX, ray
# Successfully installed ray-2.46.0 tensorboardX-2.6.2.2

# %% [markdown]
# # Env

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# !unzip -qq "/content/drive/MyDrive/MAGISTERKA/datasets/fog-combined.zip" -d "/content/datasets/"

# %%
# !pip install lightning
# Out:
# Collecting lightning
#   Downloading lightning-2.5.1.post0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.11/dist-packages (from lightning) (6.0.2)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (2025.3.2)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning)
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging<25.0,>=20.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (24.2)
# Requirement already satisfied: torch<4.0,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (2.6.0+cu124)
# Collecting torchmetrics<3.0,>=0.7.0 (from lightning)
#   Downloading torchmetrics-1.7.2-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (4.14.0)
# Collecting pytorch-lightning (from lightning)
#   Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (3.11.15)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities<2.0,>=0.10.0->lightning) (75.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<4.0,>=2.1.0->lightning) (1.3.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics<3.0,>=0.7.0->lightning) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<4.0,>=2.1.0->lightning) (3.0.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (3.10)
# Downloading lightning-2.5.1.post0-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 13.5 MB/s eta 0:00:00
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 133.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 105.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 36.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 113.7 MB/s eta 0:00:00
# Downloading torchmetrics-1.7.2-py3-none-any.whl (962 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 962.5/962.5 kB 54.7 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.1/823.1 kB 46.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchmetrics, pytorch-lightning, lightning
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed lightning-2.5.1.post0 lightning-utilities-0.14.3 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pytorch-lightning-2.5.1.post0 torchmetrics-1.7.2

# %% [markdown]
# # Setup

# %%
from pathlib import Path
from time import time

import torch
from torchvision.models import get_weight
from torchvision.transforms import v2

import numpy as np
import pandas as pd
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.base import ClassifierMixin
from typing import Any, TypeVar
from collections import namedtuple
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix

import ray
from ray import tune

# %%
base_transform = v2.Compose([
    v2.Resize((256, 256), v2.InterpolationMode.BILINEAR),
    v2.CenterCrop((224, 224)),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
])
transforms = {
    "grayscale": v2.Compose([
        base_transform,
        v2.Grayscale(num_output_channels=3)
    ]),
    "color": v2.Compose([
        base_transform,
    ]),
}

# %%
BASE_PATH = Path("/content")
DRIVE_PATH = Path("/content/drive/MyDrive/MAGISTERKA")

# %%
import sys
sys.path.insert(0, str(DRIVE_PATH / 'src'))
from cnn_model import CNNClassifier, get_dataloader

# %%
DATASET_PATHS = {
    'fog-detection': BASE_PATH / 'datasets/fog-detection-dataset-prepared',
    'fog-or-smog': BASE_PATH / 'datasets/fog-or-smog-detection-dataset-prepared',
    'foggy-cityscapes': BASE_PATH / 'datasets/foggy-cityscapes-image-dataset-prepared',
    'combined': BASE_PATH / 'datasets/fog-combined',
}

DATASET_NORMALIZATION = {
    'fog-detection': {'mean': [0.4850, 0.5044, 0.4878], 'std': [0.2631, 0.2524, 0.2793]},
    'fog-or-smog': {'mean': [0.5411, 0.5339, 0.5088], 'std': [0.2353, 0.2157, 0.2289]},
    'foggy-cityscapes': {'mean': [0.4169, 0.4507, 0.4173], 'std': [0.1860, 0.1835, 0.1820]},
    'combined': {'mean': [0.5017, 0.5087, 0.4826], 'std': [0.2259, 0.2118, 0.2227]}
}

# %%
def dataloader_to_df(dataloader):
  X = []
  y = []
  for images, labels in dataloader:
    for image, label in zip(images, labels):
      X.append(image.numpy().reshape(-1))
      y.append(label.numpy().item())
  df = pd.DataFrame({'features': X, 'class': y})
  return df

# %%
set(DATASET_PATHS.keys()) - {'combined'}
# Out:
# {'fog-detection', 'fog-or-smog', 'foggy-cityscapes'}

# %%
dfs_color = {
    dataset: {
        'train': dataloader_to_df(get_dataloader(DATASET_PATHS[dataset] / 'train', transforms["color"])),
        'val': dataloader_to_df(get_dataloader(DATASET_PATHS[dataset] / 'val', transforms["color"])),
        'test': dataloader_to_df(get_dataloader(DATASET_PATHS[dataset] / 'test', transforms["color"]))
    } for dataset in (set(DATASET_PATHS.keys()) - {'combined'})
}

# dfs_grayscale = {
#     dataset: {
#         'train': dataloader_to_df(get_dataloader(DATASET_PATHS[dataset] / 'train', transforms["grayscale"])),
#         'val': dataloader_to_df(get_dataloader(DATASET_PATHS[dataset] / 'val', transforms["grayscale"])),
#         'test': dataloader_to_df(get_dataloader(DATASET_PATHS[dataset] / 'test', transforms["grayscale"]))
#     } for dataset in (set(DATASET_PATHS.keys()) - {'combined'})
# }

# %%
dfs_color['combined'] = {}
for split in ['train', 'val', 'test']:
  dfs_combined = [dfs_color[dataset][split] for dataset in (set(DATASET_PATHS.keys()) - {'combined'})]
  dfs_combined = pd.concat(dfs_combined)
  dfs_color['combined'][split] = dfs_combined

# %%
_T = TypeVar('_T', bound=ClassifierMixin)

def evaluate_classic_model(model: _T, X: Any, y: Any):
    y_pred = model.predict(X)
    accuracy = accuracy_score(y, y_pred)
    f1 = f1_score(y, y_pred, average='macro')
    precision = precision_score(y, y_pred, average='macro')
    recall = recall_score(y, y_pred, average='macro')
    confusion = confusion_matrix(y, y_pred)
    return namedtuple('Evaluation', ['accuracy', 'f1', 'precision', 'recall', 'confusion'])(accuracy, f1, precision, recall, confusion)

def _get_formatted_metric(values: list[float]):
  avg = sum(values) / len(values)
  std = (sum([(v - avg) ** 2 for v in values]) / len(values)) ** 0.5
  return f"{avg:.4f} ± {std:.4f}"

def train_model(
    model_cls: _T,
    model_kwargs: dict[str, Any],
    train_df: pd.DataFrame,
) -> _T:
    model = model_cls(**model_kwargs)
    model.fit(np.stack(train_df['features'].values), train_df['class'])
    return model

def run_model(
    model_cls: _T,
    model_kwargs: dict[str, Any],
    train_df: pd.DataFrame,
    # val_df: pd.DataFrame,
    test_dfs: dict[str, pd.DataFrame],
    repeat: int = 5,
    transform: str = "color",
    normalize: bool = False
):
  final_res = {
      dataset: {
          'accuracy': [],
          'f1': [],
          'precision': [],
          'recall': [],
      } for dataset in test_dfs.keys()
  }
  training_times = []
  for i in range(repeat):

    _start = time()
    model = train_model(
        model_cls=model_cls,
        model_kwargs=model_kwargs,
        train_df=train_df,
        # val_df=val_df
    )
    _end = time()
    training_times.append(_end - _start)
    for dataset, test_df in test_dfs.items():
      results = evaluate_classic_model(
          model=model,
          X=np.stack(test_df['features'].values),
          y=test_df['class']
      )
      final_res[dataset]['accuracy'].append(results.accuracy)
      final_res[dataset]['f1'].append(results.f1)
      final_res[dataset]['precision'].append(results.precision)
      final_res[dataset]['recall'].append(results.recall)
  print(final_res)
  latex_table = [
    [
      dataset,
      *[_get_formatted_metric(m) for m in metrics.values()]
    ] for dataset, metrics in final_res.items()
  ]
  latex_table_str = ""
  for line in latex_table:
    latex_table_str += " & ".join([str(l) for l in line]) + " \\\\\n"

  return latex_table_str

# %% [markdown]
# # Ray Tune

# %%
import ray
from ray import tune

# %%
def subsample_df(df: pd.DataFrame, frac: float, target_column: str='class') -> pd.DataFrame:
  dfs = []
  for class_name in df[target_column].unique():
    class_df = df[df[target_column] == class_name]
    class_df = class_df.sample(frac=frac)
    dfs.append(class_df)
  return pd.concat(dfs)

# %%
def train_model_tune(
    config,
    model_cls: _T,
    train_df: pd.DataFrame,
    val_df: pd.DataFrame
):
  model = model_cls(**config)

  model.fit(np.stack(train_df['features'].values), train_df['class'])
  val_metrics = evaluate_classic_model(model, np.stack(val_df['features'].values), val_df['class'])

  tune.report(
      {
    "accuracy": val_metrics.accuracy,
    "f1": val_metrics.f1,
    "precision": val_metrics.precision,
    "recall": val_metrics.recall
      }
  )

# %% [markdown]
# # SVC

# %%
tuner = tune.Tuner(
    tune.with_parameters(
        train_model_tune,
        model_cls=LinearSVC,
        train_df=subsample_df(dfs_color['combined']['train'], frac=0.05),
        val_df=dfs_color['combined']['val']
    ),
    param_space={
        "C": tune.grid_search([0.01, 0.1, 0.4, 0.8, 1, 1.2, 2.0, 10]),
    }
)

results = tuner.fit()
# Out:
# +-------------------------------------------------------------------------+
# | Configuration for experiment     train_model_tune_2025-06-07_23-47-44   |
# +-------------------------------------------------------------------------+
# | Search algorithm                 BasicVariantGenerator                  |
# | Scheduler                        FIFOScheduler                          |
# | Number of trials                 8                                      |
# +-------------------------------------------------------------------------+
#
# View detailed results here: /root/ray_results/train_model_tune_2025-06-07_23-47-44
# To visualize your results with TensorBoard, run: `tensorboard --logdir /tmp/ray/session_2025-06-07_22-18-50_111809_13588/artifacts/2025-06-07_23-47-44/train_model_tune_2025-06-07_23-47-44/driver_artifacts`
#
# Trial status: 8 PENDING
# Current time: 2025-06-07 23:47:44. Total running time: 0s
# Logical resource usage: 0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                     status         C |
# +-------------------------------------------------+
# | train_model_tune_cef85_00000   PENDING     0.01 |
# | train_model_tune_cef85_00001   PENDING     0.1  |
# | train_model_tune_cef85_00002   PENDING     0.4  |
# | train_model_tune_cef85_00003   PENDING     0.8  |
# | train_model_tune_cef85_00004   PENDING     1    |
# | train_model_tune_cef85_00005   PENDING     1.2  |
# | train_model_tune_cef85_00006   PENDING     2    |
# | train_model_tune_cef85_00007   PENDING    10    |
# +-------------------------------------------------+
#
# Trial train_model_tune_cef85_00005 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_cef85_00005 config         |
# +---------------------------------------------------+
# | C                                             1.2 |
# +---------------------------------------------------+
#
# Trial train_model_tune_cef85_00001 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_cef85_00001 config         |
# +---------------------------------------------------+
# | C                                             0.1 |
# +---------------------------------------------------+
#
# Trial train_model_tune_cef85_00000 started with configuration:
# +----------------------------------------------------+
# | Trial train_model_tune_cef85_00000 config          |
# +----------------------------------------------------+
# | C                                             0.01 |
# +----------------------------------------------------+
#
# Trial train_model_tune_cef85_00004 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_cef85_00004 config        |
# +--------------------------------------------------+
# | C                                              1 |
# +--------------------------------------------------+
#
# Trial train_model_tune_cef85_00006 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_cef85_00006 config        |
# +--------------------------------------------------+
# | C                                              2 |
# +--------------------------------------------------+
#
# Trial train_model_tune_cef85_00007 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_cef85_00007 config        |
# +--------------------------------------------------+
# | C                                             10 |
# +--------------------------------------------------+
#
# Trial train_model_tune_cef85_00002 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_cef85_00002 config         |
# +---------------------------------------------------+
# | C                                             0.4 |
# +---------------------------------------------------+
#
# Trial train_model_tune_cef85_00003 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_cef85_00003 config         |
# +---------------------------------------------------+
# | C                                             0.8 |
# +---------------------------------------------------+
#
# Trial status: 8 RUNNING
# Current time: 2025-06-07 23:48:14. Total running time: 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                     status         C |
# +-------------------------------------------------+
# | train_model_tune_cef85_00000   RUNNING     0.01 |
# | train_model_tune_cef85_00001   RUNNING     0.1  |
# | train_model_tune_cef85_00002   RUNNING     0.4  |
# | train_model_tune_cef85_00003   RUNNING     0.8  |
# | train_model_tune_cef85_00004   RUNNING     1    |
# | train_model_tune_cef85_00005   RUNNING     1.2  |
# | train_model_tune_cef85_00006   RUNNING     2    |
# | train_model_tune_cef85_00007   RUNNING    10    |
# +-------------------------------------------------+
# (train_model_tune pid=42558) /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
# (train_model_tune pid=42558)   warnings.warn(
# Trial train_model_tune_cef85_00003 completed after 1 iterations at 2025-06-07 23:48:44. Total running time: 1min 0s
# +-------------------------------------------------------+
# | Trial train_model_tune_cef85_00003 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              56.0662 |
# | time_total_s                                  56.0662 |
# | training_iteration                                  1 |
# | accuracy                                       0.6514 |
# | f1                                            0.62058 |
# | precision                                     0.69067 |
# | recall                                        0.63912 |
# +-------------------------------------------------------+
#
# Trial status: 7 RUNNING | 1 TERMINATED
# Current time: 2025-06-07 23:48:45. Total running time: 1min 0s
# Logical resource usage: 7.0/8 CPUs, 0/0 GPUs
# +--------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status           C     iter     total time (s)     accuracy         f1     precision     recall |
# +--------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_cef85_00000   RUNNING       0.01                                                                              |
# | train_model_tune_cef85_00001   RUNNING       0.1                                                                               |
# | train_model_tune_cef85_00002   RUNNING       0.4                                                                               |
# | train_model_tune_cef85_00004   RUNNING       1                                                                                 |
# | train_model_tune_cef85_00005   RUNNING       1.2                                                                               |
# | train_model_tune_cef85_00006   RUNNING       2                                                                                 |
# | train_model_tune_cef85_00007   RUNNING      10                                                                                 |
# | train_model_tune_cef85_00003   TERMINATED    0.8         1            56.0662     0.651399   0.620584      0.690671   0.639115 |
# +--------------------------------------------------------------------------------------------------------------------------------+
#
# Trial train_model_tune_cef85_00002 completed after 1 iterations at 2025-06-07 23:48:45. Total running time: 1min 0s
# +-------------------------------------------------------+
# | Trial train_model_tune_cef85_00002 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              56.6332 |
# | time_total_s                                  56.6332 |
# | training_iteration                                  1 |
# | accuracy                                       0.6514 |
# | f1                                            0.62177 |
# | precision                                     0.68829 |
# | recall                                        0.63936 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_cef85_00006 completed after 1 iterations at 2025-06-07 23:48:45. Total running time: 1min 0s
# +-------------------------------------------------------+
# | Trial train_model_tune_cef85_00006 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              56.6919 |
# | time_total_s                                  56.6919 |
# | training_iteration                                  1 |
# | accuracy                                      0.64885 |
# | f1                                            0.61841 |
# | precision                                     0.68599 |
# | recall                                        0.63669 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_cef85_00004 completed after 1 iterations at 2025-06-07 23:48:45. Total running time: 1min 0s
# +-------------------------------------------------------+
# | Trial train_model_tune_cef85_00004 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              56.7867 |
# | time_total_s                                  56.7867 |
# | training_iteration                                  1 |
# | accuracy                                       0.6514 |
# | f1                                            0.62058 |
# | precision                                     0.69067 |
# | recall                                        0.63912 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_cef85_00007 completed after 1 iterations at 2025-06-07 23:48:45. Total running time: 1min 0s
# +-------------------------------------------------------+
# | Trial train_model_tune_cef85_00007 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              56.8207 |
# | time_total_s                                  56.8207 |
# | training_iteration                                  1 |
# | accuracy                                      0.64885 |
# | f1                                            0.61959 |
# | precision                                     0.68372 |
# | recall                                        0.63693 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_cef85_00005 completed after 1 iterations at 2025-06-07 23:48:45. Total running time: 1min 1s
# +-------------------------------------------------------+
# | Trial train_model_tune_cef85_00005 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              57.1929 |
# | time_total_s                                  57.1929 |
# | training_iteration                                  1 |
# | accuracy                                       0.6514 |
# | f1                                            0.62058 |
# | precision                                     0.69067 |
# | recall                                        0.63912 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_cef85_00001 completed after 1 iterations at 2025-06-07 23:48:45. Total running time: 1min 1s
# +-------------------------------------------------------+
# | Trial train_model_tune_cef85_00001 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              57.3098 |
# | time_total_s                                  57.3098 |
# | training_iteration                                  1 |
# | accuracy                                      0.65394 |
# | f1                                            0.62276 |
# | precision                                     0.69543 |
# | recall                                        0.64154 |
# +-------------------------------------------------------+
# 2025-06-07 23:48:47,785	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/root/ray_results/train_model_tune_2025-06-07_23-47-44' in 0.0090s.
# Trial train_model_tune_cef85_00000 completed after 1 iterations at 2025-06-07 23:48:47. Total running time: 1min 3s
# +-------------------------------------------------------+
# | Trial train_model_tune_cef85_00000 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              59.1365 |
# | time_total_s                                  59.1365 |
# | training_iteration                                  1 |
# | accuracy                                      0.66921 |
# | f1                                            0.63704 |
# | precision                                     0.72261 |
# | recall                                        0.65635 |
# +-------------------------------------------------------+
#
# Trial status: 8 TERMINATED
# Current time: 2025-06-07 23:48:47. Total running time: 1min 3s
# Logical resource usage: 1.0/8 CPUs, 0/0 GPUs
# +--------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status           C     iter     total time (s)     accuracy         f1     precision     recall |
# +--------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_cef85_00000   TERMINATED    0.01        1            59.1365     0.669211   0.637042      0.722612   0.656352 |
# | train_model_tune_cef85_00001   TERMINATED    0.1         1            57.3098     0.653944   0.622756      0.69543    0.641542 |
# | train_model_tune_cef85_00002   TERMINATED    0.4         1            56.6332     0.651399   0.621768      0.688289   0.639362 |
# | train_model_tune_cef85_00003   TERMINATED    0.8         1            56.0662     0.651399   0.620584      0.690671   0.639115 |
# | train_model_tune_cef85_00004   TERMINATED    1           1            56.7867     0.651399   0.620584      0.690671   0.639115 |
# 'foggy-cityscapes & 0.6697 ± 0.0040 & 0.6605 ± 0.0037 & 0.6904 ± 0.0056 & 0.6697 ± 0.0040 \\\\\nfog-detection & 0.8585 ± 0.0000 & 0.8363 ± 0.0000 & 0.9062 ± 0.0000 & 0.8171 ± 0.0000 \\\\\nfog-or-smog & 0.8737 ± 0.0011 & 0.8722 ± 0.0011 & 0.8837 ± 0.0008 & 0.8710 ± 0.0011 \\\\\ncombined & 0.8190 ± 0.0008 & 0.8143 ± 0.0008 & 0.8361 ± 0.0013 & 0.8129 ± 0.0008 \\\\\n'

# %% [markdown]
# # RFC

# %%
tuner = tune.Tuner(
    tune.with_parameters(
        train_model_tune,
        model_cls=RandomForestClassifier,
        # train_df=dfs_color['combined']['train'],
        train_df=subsample_df(dfs_color['combined']['train'], frac=0.2),
        val_df=dfs_color['combined']['val']
    ),
    param_space={
        "n_estimators": tune.grid_search([10, 50, 100, 200]),
        "max_depth": tune.grid_search([1, 5, 10, 20, 50, None]),
    }
)

results = tuner.fit()
# Out:
# 2025-06-07 22:18:51,551	INFO worker.py:1888 -- Started a local Ray instance.
# 2025-06-07 22:18:54,641	INFO tune.py:253 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `Tuner(...)`.
# +-------------------------------------------------------------------------+
# | Configuration for experiment     train_model_tune_2025-06-07_22-18-50   |
# +-------------------------------------------------------------------------+
# | Search algorithm                 BasicVariantGenerator                  |
# | Scheduler                        FIFOScheduler                          |
# | Number of trials                 24                                     |
# +-------------------------------------------------------------------------+
#
# View detailed results here: /root/ray_results/train_model_tune_2025-06-07_22-18-50
# To visualize your results with TensorBoard, run: `tensorboard --logdir /tmp/ray/session_2025-06-07_22-18-50_111809_13588/artifacts/2025-06-07_22-18-54/train_model_tune_2025-06-07_22-18-50/driver_artifacts`
#
# Trial status: 24 PENDING
# Current time: 2025-06-07 22:18:55. Total running time: 0s
# Logical resource usage: 0/8 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------+
# | Trial name                     status       n_estimators     max_depth |
# +------------------------------------------------------------------------+
# | train_model_tune_6607c_00000   PENDING                10             1 |
# | train_model_tune_6607c_00001   PENDING                10             5 |
# | train_model_tune_6607c_00002   PENDING                10            10 |
# | train_model_tune_6607c_00003   PENDING                10            20 |
# | train_model_tune_6607c_00004   PENDING                10            50 |
# +------------------------------------------------------------------------+
# 19 more PENDING
#
# Trial train_model_tune_6607c_00001 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_6607c_00001 config        |
# +--------------------------------------------------+
# | max_depth                                      5 |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial train_model_tune_6607c_00007 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_6607c_00007 config        |
# +--------------------------------------------------+
# | max_depth                                      5 |
# | n_estimators                                  50 |
# +--------------------------------------------------+
#
# Trial train_model_tune_6607c_00000 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_6607c_00000 config        |
# +--------------------------------------------------+
# | max_depth                                      1 |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial train_model_tune_6607c_00006 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_6607c_00006 config        |
# +--------------------------------------------------+
# | max_depth                                      1 |
# | n_estimators                                  50 |
# +--------------------------------------------------+
#
# Trial train_model_tune_6607c_00003 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_6607c_00003 config        |
# +--------------------------------------------------+
# | max_depth                                     20 |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial train_model_tune_6607c_00004 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_6607c_00004 config        |
# +--------------------------------------------------+
# | max_depth                                     50 |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial train_model_tune_6607c_00005 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_6607c_00005 config        |
# +--------------------------------------------------+
# | max_depth                                        |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial train_model_tune_6607c_00002 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_6607c_00002 config        |
# +--------------------------------------------------+
# | max_depth                                     10 |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial train_model_tune_6607c_00000 completed after 1 iterations at 2025-06-07 22:19:00. Total running time: 5s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00000 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              1.05054 |
# | time_total_s                                  1.05054 |
# | training_iteration                                  1 |
# | accuracy                                      0.78117 |
# | f1                                            0.77742 |
# | precision                                     0.78895 |
# | recall                                        0.77671 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00001 completed after 1 iterations at 2025-06-07 22:19:00. Total running time: 5s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00001 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              1.40636 |
# | time_total_s                                  1.40636 |
# | training_iteration                                  1 |
# | accuracy                                      0.83206 |
# | f1                                            0.83167 |
# | precision                                     0.83167 |
# | recall                                        0.83167 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00003 completed after 1 iterations at 2025-06-07 22:19:00. Total running time: 5s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00003 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                               1.5218 |
# | time_total_s                                   1.5218 |
# | training_iteration                                  1 |
# | accuracy                                      0.80407 |
# | f1                                            0.80407 |
# | precision                                     0.80654 |
# | recall                                         0.8062 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00004 completed after 1 iterations at 2025-06-07 22:19:00. Total running time: 6s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00004 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              1.57052 |
# | time_total_s                                  1.57052 |
# | training_iteration                                  1 |
# | accuracy                                      0.80916 |
# | f1                                            0.80866 |
# | precision                                     0.80875 |
# | recall                                        0.80859 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00006 completed after 1 iterations at 2025-06-07 22:19:00. Total running time: 6s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00006 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              1.70333 |
# | time_total_s                                  1.70333 |
# | training_iteration                                  1 |
# | accuracy                                      0.76845 |
# | f1                                            0.76523 |
# | precision                                     0.77339 |
# | recall                                        0.76458 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00005 completed after 1 iterations at 2025-06-07 22:19:01. Total running time: 6s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00005 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              1.74409 |
# | time_total_s                                  1.74409 |
# | training_iteration                                  1 |
# | accuracy                                      0.80407 |
# | f1                                            0.80405 |
# | precision                                     0.80499 |
# | recall                                        0.80546 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00002 completed after 1 iterations at 2025-06-07 22:19:01. Total running time: 6s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00002 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                               1.8456 |
# | time_total_s                                   1.8456 |
# | training_iteration                                  1 |
# | accuracy                                      0.84733 |
# | f1                                            0.84725 |
# | precision                                     0.84739 |
# | recall                                         0.8482 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00007 completed after 1 iterations at 2025-06-07 22:19:03. Total running time: 8s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00007 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              4.42942 |
# | time_total_s                                  4.42942 |
# | training_iteration                                  1 |
# | accuracy                                      0.82952 |
# | f1                                            0.82907 |
# | precision                                     0.82916 |
# | recall                                        0.82899 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00008 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_6607c_00008 config        |
# +--------------------------------------------------+
# | max_depth                                     10 |
# | n_estimators                                  50 |
# +--------------------------------------------------+
#
# Trial train_model_tune_6607c_00011 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_6607c_00011 config        |
# +--------------------------------------------------+
# | max_depth                                        |
# | n_estimators                                  50 |
# +--------------------------------------------------+
#
# Trial train_model_tune_6607c_00009 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_6607c_00009 config        |
# +--------------------------------------------------+
# | max_depth                                     20 |
# | n_estimators                                  50 |
# +--------------------------------------------------+
#
# Trial train_model_tune_6607c_00010 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_6607c_00010 config        |
# +--------------------------------------------------+
# | max_depth                                     50 |
# | n_estimators                                  50 |
# +--------------------------------------------------+
#
# Trial train_model_tune_6607c_00013 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_6607c_00013 config         |
# +---------------------------------------------------+
# | max_depth                                       5 |
# | n_estimators                                  100 |
# +---------------------------------------------------+
#
# Trial train_model_tune_6607c_00012 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_6607c_00012 config         |
# +---------------------------------------------------+
# | max_depth                                       1 |
# | n_estimators                                  100 |
# +---------------------------------------------------+
#
# Trial train_model_tune_6607c_00014 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_6607c_00014 config         |
# +---------------------------------------------------+
# | max_depth                                      10 |
# | n_estimators                                  100 |
# +---------------------------------------------------+
#
# Trial train_model_tune_6607c_00015 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_6607c_00015 config         |
# +---------------------------------------------------+
# | max_depth                                      20 |
# | n_estimators                                  100 |
# +---------------------------------------------------+
#
# Trial train_model_tune_6607c_00012 completed after 1 iterations at 2025-06-07 22:19:07. Total running time: 12s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00012 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              2.08892 |
# | time_total_s                                  2.08892 |
# | training_iteration                                  1 |
# | accuracy                                      0.77354 |
# | f1                                            0.77066 |
# | precision                                     0.77786 |
# | recall                                        0.76992 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00008 completed after 1 iterations at 2025-06-07 22:19:09. Total running time: 14s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00008 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              5.54094 |
# | time_total_s                                  5.54094 |
# | training_iteration                                  1 |
# | accuracy                                      0.84987 |
# | f1                                            0.84978 |
# | precision                                     0.84981 |
# | recall                                        0.85063 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00011 completed after 1 iterations at 2025-06-07 22:19:10. Total running time: 15s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00011 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              5.32025 |
# | time_total_s                                  5.32025 |
# | training_iteration                                  1 |
# | accuracy                                       0.8626 |
# | f1                                            0.86249 |
# | precision                                     0.86243 |
# | recall                                        0.86326 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00010 completed after 1 iterations at 2025-06-07 22:19:10. Total running time: 15s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00010 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              5.47414 |
# | time_total_s                                  5.47414 |
# | training_iteration                                  1 |
# | accuracy                                      0.85496 |
# | f1                                            0.85478 |
# | precision                                     0.85459 |
# | recall                                        0.85524 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00009 completed after 1 iterations at 2025-06-07 22:19:10. Total running time: 16s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00009 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              5.60408 |
# | time_total_s                                  5.60408 |
# | training_iteration                                  1 |
# | accuracy                                      0.84478 |
# | f1                                            0.84464 |
# | precision                                     0.84453 |
# | recall                                        0.84528 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00016 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_6607c_00016 config         |
# +---------------------------------------------------+
# | max_depth                                      50 |
# | n_estimators                                  100 |
# +---------------------------------------------------+
#
# Trial train_model_tune_6607c_00017 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_6607c_00017 config         |
# +---------------------------------------------------+
# | max_depth                                         |
# | n_estimators                                  100 |
# +---------------------------------------------------+
#
# Trial train_model_tune_6607c_00013 completed after 1 iterations at 2025-06-07 22:19:14. Total running time: 19s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00013 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              8.45851 |
# | time_total_s                                  8.45851 |
# | training_iteration                                  1 |
# | accuracy                                      0.83461 |
# | f1                                            0.83388 |
# | precision                                     0.83494 |
# | recall                                        0.83335 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00018 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_6607c_00018 config         |
# +---------------------------------------------------+
# | max_depth                                       1 |
# | n_estimators                                  200 |
# +---------------------------------------------------+
#
# Trial train_model_tune_6607c_00019 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_6607c_00019 config         |
# +---------------------------------------------------+
# | max_depth                                       5 |
# | n_estimators                                  200 |
# +---------------------------------------------------+
#
# Trial train_model_tune_6607c_00020 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_6607c_00020 config         |
# +---------------------------------------------------+
# | max_depth                                      10 |
# | n_estimators                                  200 |
# +---------------------------------------------------+
#
# Trial train_model_tune_6607c_00014 completed after 1 iterations at 2025-06-07 22:19:16. Total running time: 21s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00014 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              10.6789 |
# | time_total_s                                  10.6789 |
# | training_iteration                                  1 |
# | accuracy                                      0.85751 |
# | f1                                            0.85735 |
# | precision                                     0.85719 |
# | recall                                        0.85791 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00021 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_6607c_00021 config         |
# +---------------------------------------------------+
# | max_depth                                      20 |
# | n_estimators                                  200 |
# +---------------------------------------------------+
#
# Trial train_model_tune_6607c_00015 completed after 1 iterations at 2025-06-07 22:19:17. Total running time: 23s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00015 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              10.4458 |
# | time_total_s                                  10.4458 |
# | training_iteration                                  1 |
# | accuracy                                       0.8626 |
# | f1                                            0.86244 |
# | precision                                     0.86228 |
# | recall                                        0.86301 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00018 completed after 1 iterations at 2025-06-07 22:19:19. Total running time: 24s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00018 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                                3.866 |
# | time_total_s                                    3.866 |
# | training_iteration                                  1 |
# | accuracy                                       0.7659 |
# | f1                                            0.76307 |
# | precision                                     0.76962 |
# | recall                                         0.7624 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00022 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_6607c_00022 config         |
# +---------------------------------------------------+
# | max_depth                                      50 |
# | n_estimators                                  200 |
# +---------------------------------------------------+
#
# Trial train_model_tune_6607c_00023 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_6607c_00023 config         |
# +---------------------------------------------------+
# | max_depth                                         |
# | n_estimators                                  200 |
# +---------------------------------------------------+
#
# Trial train_model_tune_6607c_00016 completed after 1 iterations at 2025-06-07 22:19:22. Total running time: 27s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00016 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              10.5796 |
# | time_total_s                                  10.5796 |
# | training_iteration                                  1 |
# | accuracy                                      0.84987 |
# | f1                                            0.84978 |
# | precision                                     0.84981 |
# | recall                                        0.85063 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00017 completed after 1 iterations at 2025-06-07 22:19:23. Total running time: 28s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00017 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              10.5598 |
# | time_total_s                                  10.5598 |
# | training_iteration                                  1 |
# | accuracy                                      0.84224 |
# | f1                                            0.84201 |
# | precision                                     0.84183 |
# | recall                                        0.84236 |
# +-------------------------------------------------------+
#
# Trial status: 19 TERMINATED | 5 RUNNING
# Current time: 2025-06-07 22:19:25. Total running time: 30s
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_6607c_00019   RUNNING                 200             5                                                                              |
# | train_model_tune_6607c_00020   RUNNING                 200            10                                                                              |
# | train_model_tune_6607c_00021   RUNNING                 200            20                                                                              |
# | train_model_tune_6607c_00022   RUNNING                 200            50                                                                              |
# | train_model_tune_6607c_00023   RUNNING                 200                                                                                            |
# | train_model_tune_6607c_00000   TERMINATED               10             1        1            1.05054     0.78117    0.777422      0.788954   0.776712 |
# | train_model_tune_6607c_00001   TERMINATED               10             5        1            1.40636     0.832061   0.831668      0.831668   0.831668 |
# | train_model_tune_6607c_00002   TERMINATED               10            10        1            1.8456      0.847328   0.847248      0.847392   0.848204 |
# | train_model_tune_6607c_00003   TERMINATED               10            20        1            1.5218      0.804071   0.804066      0.806536   0.806202 |
# | train_model_tune_6607c_00004   TERMINATED               10            50        1            1.57052     0.80916    0.808665      0.80875    0.80859  |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 14 more TERMINATED
#
# Trial train_model_tune_6607c_00019 completed after 1 iterations at 2025-06-07 22:19:29. Total running time: 34s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00019 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              14.0979 |
# | time_total_s                                  14.0979 |
# | training_iteration                                  1 |
# | accuracy                                      0.85242 |
# | f1                                            0.85214 |
# | precision                                     0.85201 |
# | recall                                        0.85232 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00020 completed after 1 iterations at 2025-06-07 22:19:33. Total running time: 38s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00020 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              17.7274 |
# | time_total_s                                  17.7274 |
# | training_iteration                                  1 |
# | accuracy                                       0.8626 |
# | f1                                            0.86249 |
# | precision                                     0.86243 |
# | recall                                        0.86326 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00021 completed after 1 iterations at 2025-06-07 22:19:35. Total running time: 40s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00021 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              17.7425 |
# | time_total_s                                  17.7425 |
# | training_iteration                                  1 |
# | accuracy                                      0.86768 |
# | f1                                            0.86758 |
# | precision                                     0.86752 |
# | recall                                        0.86836 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_6607c_00022 completed after 1 iterations at 2025-06-07 22:19:37. Total running time: 42s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00022 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              17.2052 |
# | time_total_s                                  17.2052 |
# | training_iteration                                  1 |
# | accuracy                                      0.84987 |
# | f1                                            0.84973 |
# | precision                                     0.84962 |
# | recall                                        0.85038 |
# +-------------------------------------------------------+
# 2025-06-07 22:19:38,556	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/root/ray_results/train_model_tune_2025-06-07_22-18-50' in 0.0095s.
# Trial train_model_tune_6607c_00023 completed after 1 iterations at 2025-06-07 22:19:38. Total running time: 43s
# +-------------------------------------------------------+
# | Trial train_model_tune_6607c_00023 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                               16.798 |
# | time_total_s                                   16.798 |
# | training_iteration                                  1 |
# | accuracy                                      0.85242 |
# | f1                                            0.85226 |
# | precision                                      0.8521 |
# | recall                                        0.85281 |
# +-------------------------------------------------------+
#
# Trial status: 24 TERMINATED
# Current time: 2025-06-07 22:19:38. Total running time: 43s
# Logical resource usage: 1.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_6607c_00000   TERMINATED               10             1        1            1.05054     0.78117    0.777422      0.788954   0.776712 |
# | train_model_tune_6607c_00001   TERMINATED               10             5        1            1.40636     0.832061   0.831668      0.831668   0.831668 |
# | train_model_tune_6607c_00002   TERMINATED               10            10        1            1.8456      0.847328   0.847248      0.847392   0.848204 |
# | train_model_tune_6607c_00003   TERMINATED               10            20        1            1.5218      0.804071   0.804066      0.806536   0.806202 |
# | train_model_tune_6607c_00004   TERMINATED               10            50        1            1.57052     0.80916    0.808665      0.80875    0.80859  |
# | train_model_tune_6607c_00005   TERMINATED               10                      1            1.74409     0.804071   0.804051      0.804987   0.805462 |
# | train_model_tune_6607c_00006   TERMINATED               50             1        1            1.70333     0.768448   0.765231      0.773391   0.764576 |
# | train_model_tune_6607c_00007   TERMINATED               50             5        1            4.42942     0.829517   0.829074      0.829165   0.828994 |
# | train_model_tune_6607c_00008   TERMINATED               50            10        1            5.54094     0.849873   0.849776      0.849814   0.850631 |
# | train_model_tune_6607c_00009   TERMINATED               50            20        1            5.60408     0.844784   0.844639      0.844532   0.845283 |
# | train_model_tune_6607c_00010   TERMINATED               50            50        1            5.47414     0.854962   0.854778      0.854594   0.855239 |
# | train_model_tune_6607c_00011   TERMINATED               50                      1            5.32025     0.862595   0.862488      0.862432   0.86326  |
# | train_model_tune_6607c_00012   TERMINATED              100             1        1            2.08892     0.773537   0.770662      0.777858   0.769924 |
# | train_model_tune_6607c_00013   TERMINATED              100             5        1            8.45851     0.834606   0.833879      0.834937   0.833355 |
# 'fog-detection & 0.9906 ± 0.0060 & 0.9900 ± 0.0063 & 0.9925 ± 0.0047 & 0.9878 ± 0.0077 \\\\\nfog-or-smog & 0.9448 ± 0.0057 & 0.9448 ± 0.0057 & 0.9453 ± 0.0058 & 0.9457 ± 0.0058 \\\\\nfoggy-cityscapes & 0.8192 ± 0.0074 & 0.8180 ± 0.0074 & 0.8280 ± 0.0081 & 0.8192 ± 0.0074 \\\\\ncombined & 0.9187 ± 0.0046 & 0.9187 ± 0.0046 & 0.9194 ± 0.0046 & 0.9204 ± 0.0046 \\\\\n'

# %% [markdown]
# # XGBoost

# %%
tuner = tune.Tuner(
    tune.with_resources(
        tune.with_parameters(
            train_model_tune,
            model_cls=XGBClassifier,
            train_df=subsample_df(dfs_color['combined']['train'], frac=0.2),
            val_df=dfs_color['combined']['val']
        ),
        resources={"cpu": 8}
    ),
    param_space={
        "n_estimators": tune.grid_search([10, 50, 100, 200]),
        "max_depth": tune.grid_search([1, 5, 10, 20, 50, None]),

    }
)

results = tuner.fit()
# Out:
# +-------------------------------------------------------------------------+
# | Configuration for experiment     train_model_tune_2025-06-07_22-33-37   |
# +-------------------------------------------------------------------------+
# | Search algorithm                 BasicVariantGenerator                  |
# | Scheduler                        FIFOScheduler                          |
# | Number of trials                 24                                     |
# +-------------------------------------------------------------------------+
#
# View detailed results here: /root/ray_results/train_model_tune_2025-06-07_22-33-37
# To visualize your results with TensorBoard, run: `tensorboard --logdir /tmp/ray/session_2025-06-07_22-18-50_111809_13588/artifacts/2025-06-07_22-33-37/train_model_tune_2025-06-07_22-33-37/driver_artifacts`
#
# Trial status: 24 PENDING
# Current time: 2025-06-07 22:33:38. Total running time: 0s
# Logical resource usage: 0/8 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------+
# | Trial name                     status       n_estimators     max_depth |
# +------------------------------------------------------------------------+
# | train_model_tune_7476c_00000   PENDING                10             1 |
# | train_model_tune_7476c_00001   PENDING                10             5 |
# | train_model_tune_7476c_00002   PENDING                10            10 |
# | train_model_tune_7476c_00003   PENDING                10            20 |
# | train_model_tune_7476c_00004   PENDING                10            50 |
# +------------------------------------------------------------------------+
# 19 more PENDING
#
# Trial train_model_tune_7476c_00000 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_7476c_00000 config        |
# +--------------------------------------------------+
# | max_depth                                      1 |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial status: 1 RUNNING | 23 PENDING
# Current time: 2025-06-07 22:34:08. Total running time: 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------+
# | Trial name                     status       n_estimators     max_depth |
# +------------------------------------------------------------------------+
# | train_model_tune_7476c_00000   RUNNING                10             1 |
# | train_model_tune_7476c_00001   PENDING                10             5 |
# | train_model_tune_7476c_00002   PENDING                10            10 |
# | train_model_tune_7476c_00003   PENDING                10            20 |
# | train_model_tune_7476c_00004   PENDING                10            50 |
# | train_model_tune_7476c_00005   PENDING                10               |
# +------------------------------------------------------------------------+
# 18 more PENDING
#
# Trial train_model_tune_7476c_00000 completed after 1 iterations at 2025-06-07 22:34:14. Total running time: 36s
# +-------------------------------------------------------+
# | Trial train_model_tune_7476c_00000 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              32.8861 |
# | time_total_s                                  32.8861 |
# | training_iteration                                  1 |
# | accuracy                                      0.78117 |
# | f1                                            0.77876 |
# | precision                                     0.78461 |
# | recall                                        0.77795 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_7476c_00001 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_7476c_00001 config        |
# +--------------------------------------------------+
# | max_depth                                      5 |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial status: 1 TERMINATED | 1 RUNNING | 22 PENDING
# Current time: 2025-06-07 22:34:38. Total running time: 1min 0s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00001   RUNNING                  10             5                                                                              |
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861      0.78117   0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00002   PENDING                  10            10                                                                              |
# | train_model_tune_7476c_00003   PENDING                  10            20                                                                              |
# | train_model_tune_7476c_00004   PENDING                  10            50                                                                              |
# | train_model_tune_7476c_00005   PENDING                  10                                                                                            |
# | train_model_tune_7476c_00006   PENDING                  50             1                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 17 more PENDING
# Trial status: 1 TERMINATED | 1 RUNNING | 22 PENDING
# Current time: 2025-06-07 22:35:08. Total running time: 1min 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00001   RUNNING                  10             5                                                                              |
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861      0.78117   0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00002   PENDING                  10            10                                                                              |
# | train_model_tune_7476c_00003   PENDING                  10            20                                                                              |
# | train_model_tune_7476c_00004   PENDING                  10            50                                                                              |
# | train_model_tune_7476c_00005   PENDING                  10                                                                                            |
# | train_model_tune_7476c_00006   PENDING                  50             1                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 17 more PENDING
#
# Trial train_model_tune_7476c_00001 completed after 1 iterations at 2025-06-07 22:35:31. Total running time: 1min 53s
# +-------------------------------------------------------+
# | Trial train_model_tune_7476c_00001 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              74.1718 |
# | time_total_s                                  74.1718 |
# | training_iteration                                  1 |
# | accuracy                                      0.85496 |
# | f1                                            0.85451 |
# | precision                                     0.85486 |
# | recall                                        0.85425 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_7476c_00002 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_7476c_00002 config        |
# +--------------------------------------------------+
# | max_depth                                     10 |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial status: 2 TERMINATED | 1 RUNNING | 21 PENDING
# Current time: 2025-06-07 22:35:38. Total running time: 2min 0s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00002   RUNNING                  10            10                                                                              |
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00003   PENDING                  10            20                                                                              |
# | train_model_tune_7476c_00004   PENDING                  10            50                                                                              |
# | train_model_tune_7476c_00005   PENDING                  10                                                                                            |
# | train_model_tune_7476c_00006   PENDING                  50             1                                                                              |
# | train_model_tune_7476c_00007   PENDING                  50             5                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 16 more PENDING
# Trial status: 2 TERMINATED | 1 RUNNING | 21 PENDING
# Current time: 2025-06-07 22:36:08. Total running time: 2min 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00002   RUNNING                  10            10                                                                              |
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00003   PENDING                  10            20                                                                              |
# | train_model_tune_7476c_00004   PENDING                  10            50                                                                              |
# | train_model_tune_7476c_00005   PENDING                  10                                                                                            |
# | train_model_tune_7476c_00006   PENDING                  50             1                                                                              |
# | train_model_tune_7476c_00007   PENDING                  50             5                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 16 more PENDING
# Trial status: 2 TERMINATED | 1 RUNNING | 21 PENDING
# Current time: 2025-06-07 22:36:38. Total running time: 3min 0s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00002   RUNNING                  10            10                                                                              |
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00003   PENDING                  10            20                                                                              |
# | train_model_tune_7476c_00004   PENDING                  10            50                                                                              |
# | train_model_tune_7476c_00005   PENDING                  10                                                                                            |
# | train_model_tune_7476c_00006   PENDING                  50             1                                                                              |
# | train_model_tune_7476c_00007   PENDING                  50             5                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 16 more PENDING
#
# Trial train_model_tune_7476c_00002 completed after 1 iterations at 2025-06-07 22:36:41. Total running time: 3min 4s
# +-------------------------------------------------------+
# | Trial train_model_tune_7476c_00002 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              68.0744 |
# | time_total_s                                  68.0744 |
# | training_iteration                                  1 |
# | accuracy                                      0.84478 |
# | f1                                            0.84387 |
# | precision                                     0.84603 |
# | recall                                        0.84306 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_7476c_00003 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_7476c_00003 config        |
# +--------------------------------------------------+
# | max_depth                                     20 |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial status: 3 TERMINATED | 1 RUNNING | 20 PENDING
# Current time: 2025-06-07 22:37:08. Total running time: 3min 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00003   RUNNING                  10            20                                                                              |
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00002   TERMINATED               10            10        1            68.0744     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00004   PENDING                  10            50                                                                              |
# | train_model_tune_7476c_00005   PENDING                  10                                                                                            |
# | train_model_tune_7476c_00006   PENDING                  50             1                                                                              |
# | train_model_tune_7476c_00007   PENDING                  50             5                                                                              |
# | train_model_tune_7476c_00008   PENDING                  50            10                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 15 more PENDING
# Trial status: 3 TERMINATED | 1 RUNNING | 20 PENDING
# Current time: 2025-06-07 22:37:38. Total running time: 4min 0s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00003   RUNNING                  10            20                                                                              |
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00002   TERMINATED               10            10        1            68.0744     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00004   PENDING                  10            50                                                                              |
# | train_model_tune_7476c_00005   PENDING                  10                                                                                            |
# | train_model_tune_7476c_00006   PENDING                  50             1                                                                              |
# | train_model_tune_7476c_00007   PENDING                  50             5                                                                              |
# | train_model_tune_7476c_00008   PENDING                  50            10                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 15 more PENDING
#
# Trial train_model_tune_7476c_00003 completed after 1 iterations at 2025-06-07 22:38:06. Total running time: 4min 28s
# +-------------------------------------------------------+
# | Trial train_model_tune_7476c_00003 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              81.9556 |
# | time_total_s                                  81.9556 |
# | training_iteration                                  1 |
# | accuracy                                      0.84478 |
# | f1                                            0.84387 |
# | precision                                     0.84603 |
# | recall                                        0.84306 |
# +-------------------------------------------------------+
#
# Trial status: 4 TERMINATED | 20 PENDING
# Current time: 2025-06-07 22:38:08. Total running time: 4min 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00002   TERMINATED               10            10        1            68.0744     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00003   TERMINATED               10            20        1            81.9556     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00004   PENDING                  10            50                                                                              |
# | train_model_tune_7476c_00005   PENDING                  10                                                                                            |
# | train_model_tune_7476c_00006   PENDING                  50             1                                                                              |
# | train_model_tune_7476c_00007   PENDING                  50             5                                                                              |
# | train_model_tune_7476c_00008   PENDING                  50            10                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 15 more PENDING
#
# Trial train_model_tune_7476c_00004 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_7476c_00004 config        |
# +--------------------------------------------------+
# | max_depth                                     50 |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial status: 4 TERMINATED | 1 RUNNING | 19 PENDING
# Current time: 2025-06-07 22:38:38. Total running time: 5min 0s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00004   RUNNING                  10            50                                                                              |
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00002   TERMINATED               10            10        1            68.0744     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00003   TERMINATED               10            20        1            81.9556     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00005   PENDING                  10                                                                                            |
# | train_model_tune_7476c_00006   PENDING                  50             1                                                                              |
# | train_model_tune_7476c_00007   PENDING                  50             5                                                                              |
# | train_model_tune_7476c_00008   PENDING                  50            10                                                                              |
# | train_model_tune_7476c_00009   PENDING                  50            20                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 14 more PENDING
# Trial status: 4 TERMINATED | 1 RUNNING | 19 PENDING
# Current time: 2025-06-07 22:39:08. Total running time: 5min 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00004   RUNNING                  10            50                                                                              |
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00002   TERMINATED               10            10        1            68.0744     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00003   TERMINATED               10            20        1            81.9556     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00005   PENDING                  10                                                                                            |
# | train_model_tune_7476c_00006   PENDING                  50             1                                                                              |
# | train_model_tune_7476c_00007   PENDING                  50             5                                                                              |
# | train_model_tune_7476c_00008   PENDING                  50            10                                                                              |
# | train_model_tune_7476c_00009   PENDING                  50            20                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 14 more PENDING
#
# Trial train_model_tune_7476c_00004 completed after 1 iterations at 2025-06-07 22:39:16. Total running time: 5min 38s
# +-------------------------------------------------------+
# | Trial train_model_tune_7476c_00004 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              66.7708 |
# | time_total_s                                  66.7708 |
# | training_iteration                                  1 |
# | accuracy                                      0.84478 |
# | f1                                            0.84387 |
# | precision                                     0.84603 |
# | recall                                        0.84306 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_7476c_00005 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_7476c_00005 config        |
# +--------------------------------------------------+
# | max_depth                                        |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial status: 5 TERMINATED | 1 RUNNING | 18 PENDING
# Current time: 2025-06-07 22:39:38. Total running time: 6min 0s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00005   RUNNING                  10                                                                                            |
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00002   TERMINATED               10            10        1            68.0744     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00003   TERMINATED               10            20        1            81.9556     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00004   TERMINATED               10            50        1            66.7708     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00006   PENDING                  50             1                                                                              |
# | train_model_tune_7476c_00007   PENDING                  50             5                                                                              |
# | train_model_tune_7476c_00008   PENDING                  50            10                                                                              |
# | train_model_tune_7476c_00009   PENDING                  50            20                                                                              |
# | train_model_tune_7476c_00010   PENDING                  50            50                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 13 more PENDING
#
# Trial train_model_tune_7476c_00005 completed after 1 iterations at 2025-06-07 22:40:06. Total running time: 6min 28s
# +-------------------------------------------------------+
# | Trial train_model_tune_7476c_00005 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              46.2284 |
# | time_total_s                                  46.2284 |
# | training_iteration                                  1 |
# | accuracy                                      0.86768 |
# | f1                                            0.86696 |
# | precision                                     0.86892 |
# | recall                                        0.86614 |
# +-------------------------------------------------------+
#
# Trial status: 6 TERMINATED | 18 PENDING
# Current time: 2025-06-07 22:40:08. Total running time: 6min 31s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00002   TERMINATED               10            10        1            68.0744     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00003   TERMINATED               10            20        1            81.9556     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00004   TERMINATED               10            50        1            66.7708     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00006   PENDING                  50             1                                                                              |
# | train_model_tune_7476c_00007   PENDING                  50             5                                                                              |
# | train_model_tune_7476c_00008   PENDING                  50            10                                                                              |
# | train_model_tune_7476c_00009   PENDING                  50            20                                                                              |
# | train_model_tune_7476c_00010   PENDING                  50            50                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 1 more TERMINATED, 13 more PENDING
#
# Trial train_model_tune_7476c_00006 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_7476c_00006 config        |
# +--------------------------------------------------+
# | max_depth                                      1 |
# | n_estimators                                  50 |
# +--------------------------------------------------+
#
# Trial train_model_tune_7476c_00006 completed after 1 iterations at 2025-06-07 22:40:37. Total running time: 6min 59s
# +-------------------------------------------------------+
# | Trial train_model_tune_7476c_00006 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              27.9909 |
# | time_total_s                                  27.9909 |
# | training_iteration                                  1 |
# | accuracy                                      0.83461 |
# | f1                                            0.83304 |
# | precision                                     0.83821 |
# | recall                                        0.83188 |
# +-------------------------------------------------------+
#
# Trial status: 7 TERMINATED | 17 PENDING
# Current time: 2025-06-07 22:40:38. Total running time: 7min 1s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00002   TERMINATED               10            10        1            68.0744     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00003   TERMINATED               10            20        1            81.9556     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00004   TERMINATED               10            50        1            66.7708     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00007   PENDING                  50             5                                                                              |
# | train_model_tune_7476c_00008   PENDING                  50            10                                                                              |
# | train_model_tune_7476c_00009   PENDING                  50            20                                                                              |
# | train_model_tune_7476c_00010   PENDING                  50            50                                                                              |
# | train_model_tune_7476c_00011   PENDING                  50                                                                                            |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 2 more TERMINATED, 12 more PENDING
#
# Trial train_model_tune_7476c_00007 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_7476c_00007 config        |
# +--------------------------------------------------+
# | max_depth                                      5 |
# | n_estimators                                  50 |
# +--------------------------------------------------+
#
# Trial status: 7 TERMINATED | 1 RUNNING | 16 PENDING
# Current time: 2025-06-07 22:41:09. Total running time: 7min 31s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00007   RUNNING                  50             5                                                                              |
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00002   TERMINATED               10            10        1            68.0744     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00003   TERMINATED               10            20        1            81.9556     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00004   TERMINATED               10            50        1            66.7708     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00008   PENDING                  50            10                                                                              |
# | train_model_tune_7476c_00009   PENDING                  50            20                                                                              |
# | train_model_tune_7476c_00010   PENDING                  50            50                                                                              |
# | train_model_tune_7476c_00011   PENDING                  50                                                                                            |
# | train_model_tune_7476c_00012   PENDING                 100             1                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 2 more TERMINATED, 11 more PENDING
# Trial status: 7 TERMINATED | 1 RUNNING | 16 PENDING
# Current time: 2025-06-07 22:41:39. Total running time: 8min 1s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00007   RUNNING                  50             5                                                                              |
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00002   TERMINATED               10            10        1            68.0744     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00003   TERMINATED               10            20        1            81.9556     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00004   TERMINATED               10            50        1            66.7708     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00008   PENDING                  50            10                                                                              |
# | train_model_tune_7476c_00009   PENDING                  50            20                                                                              |
# | train_model_tune_7476c_00010   PENDING                  50            50                                                                              |
# | train_model_tune_7476c_00011   PENDING                  50                                                                                            |
# | train_model_tune_7476c_00012   PENDING                 100             1                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 2 more TERMINATED, 11 more PENDING
# Trial status: 7 TERMINATED | 1 RUNNING | 16 PENDING
# Current time: 2025-06-07 22:42:09. Total running time: 8min 31s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00007   RUNNING                  50             5                                                                              |
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00002   TERMINATED               10            10        1            68.0744     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00003   TERMINATED               10            20        1            81.9556     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00004   TERMINATED               10            50        1            66.7708     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00008   PENDING                  50            10                                                                              |
# | train_model_tune_7476c_00009   PENDING                  50            20                                                                              |
# | train_model_tune_7476c_00010   PENDING                  50            50                                                                              |
# | train_model_tune_7476c_00011   PENDING                  50                                                                                            |
# | train_model_tune_7476c_00012   PENDING                 100             1                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 2 more TERMINATED, 11 more PENDING
#
# Trial train_model_tune_7476c_00007 completed after 1 iterations at 2025-06-07 22:42:14. Total running time: 8min 36s
# +-------------------------------------------------------+
# | Trial train_model_tune_7476c_00007 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              94.2013 |
# | time_total_s                                  94.2013 |
# | training_iteration                                  1 |
# | accuracy                                      0.87786 |
# | f1                                            0.87737 |
# | precision                                     0.87831 |
# | recall                                        0.87684 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_7476c_00008 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_7476c_00008 config        |
# ...
# | Trial train_model_tune_7476c_00023 config         |
# +---------------------------------------------------+
# | max_depth                                         |
# | n_estimators                                  200 |
# +---------------------------------------------------+
#
# Trial status: 23 TERMINATED | 1 RUNNING
# Current time: 2025-06-07 23:18:12. Total running time: 44min 34s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00023   RUNNING                 200                                                                                            |
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00002   TERMINATED               10            10        1            68.0744     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00003   TERMINATED               10            20        1            81.9556     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00004   TERMINATED               10            50        1            66.7708     0.844784   0.843874      0.846028   0.843064 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 18 more TERMINATED
# Trial status: 23 TERMINATED | 1 RUNNING
# Current time: 2025-06-07 23:18:42. Total running time: 45min 4s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00023   RUNNING                 200                                                                                            |
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00002   TERMINATED               10            10        1            68.0744     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00003   TERMINATED               10            20        1            81.9556     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00004   TERMINATED               10            50        1            66.7708     0.844784   0.843874      0.846028   0.843064 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 18 more TERMINATED
# Trial status: 23 TERMINATED | 1 RUNNING
# Current time: 2025-06-07 23:19:12. Total running time: 45min 34s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00023   RUNNING                 200                                                                                            |
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00002   TERMINATED               10            10        1            68.0744     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00003   TERMINATED               10            20        1            81.9556     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00004   TERMINATED               10            50        1            66.7708     0.844784   0.843874      0.846028   0.843064 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 18 more TERMINATED
# Trial status: 23 TERMINATED | 1 RUNNING
# Current time: 2025-06-07 23:19:42. Total running time: 46min 4s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00023   RUNNING                 200                                                                                            |
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00002   TERMINATED               10            10        1            68.0744     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00003   TERMINATED               10            20        1            81.9556     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00004   TERMINATED               10            50        1            66.7708     0.844784   0.843874      0.846028   0.843064 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 18 more TERMINATED
# Trial status: 23 TERMINATED | 1 RUNNING
# Current time: 2025-06-07 23:20:12. Total running time: 46min 34s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00023   RUNNING                 200                                                                                            |
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00002   TERMINATED               10            10        1            68.0744     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00003   TERMINATED               10            20        1            81.9556     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00004   TERMINATED               10            50        1            66.7708     0.844784   0.843874      0.846028   0.843064 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 18 more TERMINATED
# Trial status: 23 TERMINATED | 1 RUNNING
# Current time: 2025-06-07 23:20:42. Total running time: 47min 4s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00023   RUNNING                 200                                                                                            |
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00002   TERMINATED               10            10        1            68.0744     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00003   TERMINATED               10            20        1            81.9556     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00004   TERMINATED               10            50        1            66.7708     0.844784   0.843874      0.846028   0.843064 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 18 more TERMINATED
# 2025-06-07 23:20:57,551	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/root/ray_results/train_model_tune_2025-06-07_22-33-37' in 0.0082s.
# Trial train_model_tune_7476c_00023 completed after 1 iterations at 2025-06-07 23:20:57. Total running time: 47min 19s
# +-------------------------------------------------------+
# | Trial train_model_tune_7476c_00023 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              195.046 |
# | time_total_s                                  195.046 |
# | training_iteration                                  1 |
# | accuracy                                      0.86514 |
# | f1                                            0.86464 |
# | precision                                     0.86535 |
# | recall                                        0.86421 |
# +-------------------------------------------------------+
#
# Trial status: 24 TERMINATED
# Current time: 2025-06-07 23:20:57. Total running time: 47min 19s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_7476c_00000   TERMINATED               10             1        1            32.8861     0.78117    0.778763      0.784609   0.777945 |
# | train_model_tune_7476c_00001   TERMINATED               10             5        1            74.1718     0.854962   0.854506      0.85486    0.854252 |
# | train_model_tune_7476c_00002   TERMINATED               10            10        1            68.0744     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00003   TERMINATED               10            20        1            81.9556     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00004   TERMINATED               10            50        1            66.7708     0.844784   0.843874      0.846028   0.843064 |
# | train_model_tune_7476c_00005   TERMINATED               10                      1            46.2284     0.867684   0.86696       0.868919   0.866141 |
# | train_model_tune_7476c_00006   TERMINATED               50             1        1            27.9909     0.834606   0.833045      0.838214   0.831875 |
# | train_model_tune_7476c_00007   TERMINATED               50             5        1            94.2013     0.877863   0.877366      0.87831    0.876837 |
# | train_model_tune_7476c_00008   TERMINATED               50            10        1           110.047      0.857506   0.856614      0.859161   0.855693 |
# | train_model_tune_7476c_00009   TERMINATED               50            20        1           106.877      0.857506   0.856614      0.859161   0.855693 |
# | train_model_tune_7476c_00010   TERMINATED               50            50        1           119.632      0.857506   0.856614      0.859161   0.855693 |
# 'fog-detection & 0.9717 ± 0.0000 & 0.9697 ± 0.0000 & 0.9779 ± 0.0000 & 0.9634 ± 0.0000 \\\\\nfog-or-smog & 0.9418 ± 0.0000 & 0.9417 ± 0.0000 & 0.9417 ± 0.0000 & 0.9418 ± 0.0000 \\\\\nfoggy-cityscapes & 0.8485 ± 0.0000 & 0.8483 ± 0.0000 & 0.8498 ± 0.0000 & 0.8485 ± 0.0000 \\\\\ncombined & 0.9219 ± 0.0000 & 0.9217 ± 0.0000 & 0.9215 ± 0.0000 & 0.9219 ± 0.0000 \\\\\n'

# %% [markdown]
# ## Not Deep models

# %%
run_model(
    model_cls=LinearSVC,
    model_kwargs={},
    train_df=train_df,
    val_df=val_df,
    test_df=test_df,
    repeat=1
)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model - LinearSVC
# 	Train metrics:
# 		Accuracy: 0.9981
# 		F1: 0.9981
# 		Precision: 0.9982
# 		Recall: 0.9981
# 	Validation metrics:
# 		Accuracy: 0.7888
# 		F1: 0.7797
# 		Precision: 0.8215
# 		Recall: 0.7808
# 'combined & 0.8060 ± 0.0000 & 0.7988 ± 0.0000 & 0.8328 ± 0.0000 & 0.7983 ± 0.0000 \\\\\n'

# %%
run_model(
    model_cls=LinearSVC,
    model_kwargs={},
    train_df=train_df,
    val_df=val_df,
    test_df=test_df,
    repeat=5
)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model - LinearSVC
# 	Train metrics:
# 		Accuracy: 0.9989
# 		F1: 0.9989
# 		Precision: 0.9989
# 		Recall: 0.9989
# 	Validation metrics:
# 		Accuracy: 0.7939
# 		F1: 0.7859
# 		Precision: 0.8227
# 		Recall: 0.7864
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model - LinearSVC
# 	Train metrics:
# 		Accuracy: 0.9993
# 		F1: 0.9993
# 		Precision: 0.9993
# 		Recall: 0.9992
# 	Validation metrics:
# 		Accuracy: 0.7888
# 		F1: 0.7801
# 		Precision: 0.8192
# 		Recall: 0.7810
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model - LinearSVC
# 	Train metrics:
# 		Accuracy: 0.9967
# 		F1: 0.9967
# 		Precision: 0.9966
# 		Recall: 0.9968
# 	Validation metrics:
# 		Accuracy: 0.7939
# 		F1: 0.7883
# 		Precision: 0.8111
# 		Recall: 0.7879
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model - LinearSVC
# 	Train metrics:
# 		Accuracy: 0.9981
# 		F1: 0.9981
# 		Precision: 0.9981
# 		Recall: 0.9982
# 	Validation metrics:
# 		Accuracy: 0.7964
# 		F1: 0.7907
# 		Precision: 0.8147
# 		Recall: 0.7903
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model - LinearSVC
# 	Train metrics:
# 		Accuracy: 0.9981
# 		F1: 0.9981
# 		Precision: 0.9982
# 		Recall: 0.9981
# 	Validation metrics:
# 		Accuracy: 0.7913
# 		F1: 0.7843
# 		Precision: 0.8146
# 		Recall: 0.7844
# 'combined & 0.8128 ± 0.0036 & 0.8071 ± 0.0042 & 0.8333 ± 0.0018 & 0.8060 ± 0.0040 \\\\\n'

# %%
run_model(
    model_cls=RandomForestClassifier,
    model_kwargs={},
    train_df=train_df,
    val_df=val_df,
    test_df=test_df,
    repeat=1
)
# Out:
# Model - RandomForestClassifier
# 	Train metrics:
# 		Accuracy: 1.0000
# 		F1: 1.0000
# 		Precision: 1.0000
# 		Recall: 1.0000
# 	Validation metrics:
# 		Accuracy: 0.9288
# 		F1: 0.9287
# 		Precision: 0.9286
# 		Recall: 0.9296
# 'combined & 0.9128 ± 0.0000 & 0.9127 ± 0.0000 & 0.9136 ± 0.0000 & 0.9145 ± 0.0000 \\\\\n'

# %%
run_model(
    model_cls=RandomForestClassifier,
    model_kwargs={},
    train_df=train_df,
    val_df=val_df,
    test_df=test_df,
    repeat=5
)
# Out:
# Model - RandomForestClassifier
# 	Train metrics:
# 		Accuracy: 1.0000
# 		F1: 1.0000
# 		Precision: 1.0000
# 		Recall: 1.0000
# 	Validation metrics:
# 		Accuracy: 0.9237
# 		F1: 0.9236
# 		Precision: 0.9235
# 		Recall: 0.9245
# Model - RandomForestClassifier
# 	Train metrics:
# 		Accuracy: 1.0000
# 		F1: 1.0000
# 		Precision: 1.0000
# 		Recall: 1.0000
# 	Validation metrics:
# 		Accuracy: 0.9186
# 		F1: 0.9185
# 		Precision: 0.9184
# 		Recall: 0.9194
# Model - RandomForestClassifier
# 	Train metrics:
# 		Accuracy: 1.0000
# 		F1: 1.0000
# 		Precision: 1.0000
# 		Recall: 1.0000
# 	Validation metrics:
# 		Accuracy: 0.9186
# 		F1: 0.9185
# 		Precision: 0.9182
# 		Recall: 0.9189
# Model - RandomForestClassifier
# 	Train metrics:
# 		Accuracy: 1.0000
# 		F1: 1.0000
# 		Precision: 1.0000
# 		Recall: 1.0000
# 	Validation metrics:
# 		Accuracy: 0.9237
# 		F1: 0.9236
# 		Precision: 0.9234
# 		Recall: 0.9242
# Model - RandomForestClassifier
# 	Train metrics:
# 		Accuracy: 1.0000
# 		F1: 1.0000
# 		Precision: 1.0000
# 		Recall: 1.0000
# 	Validation metrics:
# 		Accuracy: 0.9211
# 		F1: 0.9210
# 		Precision: 0.9208
# 		Recall: 0.9213
# 'combined & 0.9193 ± 0.0044 & 0.9193 ± 0.0044 & 0.9201 ± 0.0042 & 0.9210 ± 0.0042 \\\\\n'

# %%
run_model(
    model_cls=XGBClassifier,
    model_kwargs={},
    train_df=train_df,
    val_df=val_df,
    test_df=test_df,
    repeat=1
)
# Out:
# Model - XGBClassifier
# 	Train metrics:
# 		Accuracy: 1.0000
# 		F1: 1.0000
# 		Precision: 1.0000
# 		Recall: 1.0000
# 	Validation metrics:
# 		Accuracy: 0.9389
# 		F1: 0.9388
# 		Precision: 0.9386
# 		Recall: 0.9390
# 'combined & 0.9284 ± 0.0000 & 0.9282 ± 0.0000 & 0.9281 ± 0.0000 & 0.9283 ± 0.0000 \\\\\n'

# %%
run_model(
    model_cls=XGBClassifier,
    model_kwargs={},
    train_df=train_df,
    val_df=val_df,
    test_df=test_df,
    repeat=5
)
# Out:
# Model - XGBClassifier
# 	Train metrics:
# 		Accuracy: 1.0000
# 		F1: 1.0000
# 		Precision: 1.0000
# 		Recall: 1.0000
# 	Validation metrics:
# 		Accuracy: 0.9389
# 		F1: 0.9388
# 		Precision: 0.9386
# 		Recall: 0.9390
# Model - XGBClassifier
# 	Train metrics:
# 		Accuracy: 1.0000
# 		F1: 1.0000
# 		Precision: 1.0000
# 		Recall: 1.0000
# 	Validation metrics:
# 		Accuracy: 0.9389
# 		F1: 0.9388
# 		Precision: 0.9386
# 		Recall: 0.9390
