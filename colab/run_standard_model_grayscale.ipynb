# %% [markdown]
# # Ray Tune

# %%
# !pip install -U "ray[tune]"
# Out:
# Collecting ray[tune]
#   Downloading ray-2.46.0-cp311-cp311-manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (8.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (3.18.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (4.24.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (1.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (24.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (5.29.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (2.2.2)
# Collecting tensorboardX>=1.9 (from ray[tune])
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pyarrow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (18.1.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from ray[tune]) (2025.3.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from tensorboardX>=1.9->ray[tune]) (2.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray[tune]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray[tune]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray[tune]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray[tune]) (0.25.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->ray[tune]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->ray[tune]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->ray[tune]) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->ray[tune]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->ray[tune]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->ray[tune]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->ray[tune]) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->ray[tune]) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from referencing>=0.28.4->jsonschema->ray[tune]) (4.14.0)
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 5.1 MB/s eta 0:00:00
# Downloading ray-2.46.0-cp311-cp311-manylinux2014_x86_64.whl (68.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 MB 26.6 MB/s eta 0:00:00
# Installing collected packages: tensorboardX, ray
# Successfully installed ray-2.46.0 tensorboardX-2.6.2.2

# %% [markdown]
# # Env

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# !unzip -qq "/content/drive/MyDrive/MAGISTERKA/datasets/fog-combined.zip" -d "/content/datasets/"

# %%
# !pip install lightning
# Out:
# Collecting lightning
#   Downloading lightning-2.5.1.post0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.11/dist-packages (from lightning) (6.0.2)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (2025.3.2)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning)
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging<25.0,>=20.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (24.2)
# Requirement already satisfied: torch<4.0,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (2.6.0+cu124)
# Collecting torchmetrics<3.0,>=0.7.0 (from lightning)
#   Downloading torchmetrics-1.7.2-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (4.14.0)
# Collecting pytorch-lightning (from lightning)
#   Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (3.11.15)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities<2.0,>=0.10.0->lightning) (75.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<4.0,>=2.1.0->lightning)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<4.0,>=2.1.0->lightning) (1.3.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics<3.0,>=0.7.0->lightning) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<4.0,>=2.1.0->lightning) (3.0.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (3.10)
# Downloading lightning-2.5.1.post0-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 36.2 MB/s eta 0:00:00
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 39.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 39.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 34.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.5 MB/s eta 0:00:00
# Downloading torchmetrics-1.7.2-py3-none-any.whl (962 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 962.5/962.5 kB 44.4 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.1/823.1 kB 41.7 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchmetrics, pytorch-lightning, lightning
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed lightning-2.5.1.post0 lightning-utilities-0.14.3 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pytorch-lightning-2.5.1.post0 torchmetrics-1.7.2

# %% [markdown]
# # Setup

# %%
from pathlib import Path
from time import time

import torch
from torchvision.models import get_weight
from torchvision.transforms import v2

import numpy as np
import pandas as pd
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.base import ClassifierMixin
from typing import Any, TypeVar
from collections import namedtuple
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix

import ray
from ray import tune

# %%
base_transform = v2.Compose([
    v2.Resize((256, 256), v2.InterpolationMode.BILINEAR),
    v2.CenterCrop((224, 224)),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
])
transforms = {
    "grayscale": v2.Compose([
        base_transform,
        v2.Grayscale(num_output_channels=3)
    ]),
    "color": v2.Compose([
        base_transform,
    ]),
}

# %%
BASE_PATH = Path("/content")
DRIVE_PATH = Path("/content/drive/MyDrive/MAGISTERKA")

# %%
import sys
sys.path.insert(0, str(DRIVE_PATH / 'src'))
from cnn_model import CNNClassifier, get_dataloader

# %%
DATASET_PATHS = {
    'fog-detection': BASE_PATH / 'datasets/fog-detection-dataset-prepared',
    'fog-or-smog': BASE_PATH / 'datasets/fog-or-smog-detection-dataset-prepared',
    'foggy-cityscapes': BASE_PATH / 'datasets/foggy-cityscapes-image-dataset-prepared',
    'combined': BASE_PATH / 'datasets/fog-combined',
}

DATASET_NORMALIZATION = {
    'fog-detection': {'mean': [0.4850, 0.5044, 0.4878], 'std': [0.2631, 0.2524, 0.2793]},
    'fog-or-smog': {'mean': [0.5411, 0.5339, 0.5088], 'std': [0.2353, 0.2157, 0.2289]},
    'foggy-cityscapes': {'mean': [0.4169, 0.4507, 0.4173], 'std': [0.1860, 0.1835, 0.1820]},
    'combined': {'mean': [0.5017, 0.5087, 0.4826], 'std': [0.2259, 0.2118, 0.2227]}
}

# %%
def dataloader_to_df(dataloader):
  X = []
  y = []
  for images, labels in dataloader:
    for image, label in zip(images, labels):
      X.append(image.numpy().reshape(-1))
      y.append(label.numpy().item())
  df = pd.DataFrame({'features': X, 'class': y})
  return df

# %%
set(DATASET_PATHS.keys()) - {'combined'}
# Out:
# {'fog-detection', 'fog-or-smog', 'foggy-cityscapes'}

# %%
dfs_color = {
    dataset: {
        'train': dataloader_to_df(get_dataloader(DATASET_PATHS[dataset] / 'train', transforms["grayscale"])),
        'val': dataloader_to_df(get_dataloader(DATASET_PATHS[dataset] / 'val', transforms["grayscale"])),
        'test': dataloader_to_df(get_dataloader(DATASET_PATHS[dataset] / 'test', transforms["grayscale"]))
    } for dataset in (set(DATASET_PATHS.keys()) - {'combined'})
}

# dfs_grayscale = {
#     dataset: {
#         'train': dataloader_to_df(get_dataloader(DATASET_PATHS[dataset] / 'train', transforms["grayscale"])),
#         'val': dataloader_to_df(get_dataloader(DATASET_PATHS[dataset] / 'val', transforms["grayscale"])),
#         'test': dataloader_to_df(get_dataloader(DATASET_PATHS[dataset] / 'test', transforms["grayscale"]))
#     } for dataset in (set(DATASET_PATHS.keys()) - {'combined'})
# }

# %%
dfs_color['combined'] = {}
for split in ['train', 'val', 'test']:
  dfs_combined = [dfs_color[dataset][split] for dataset in (set(DATASET_PATHS.keys()) - {'combined'})]
  dfs_combined = pd.concat(dfs_combined)
  dfs_color['combined'][split] = dfs_combined

# %%
_T = TypeVar('_T', bound=ClassifierMixin)

def evaluate_classic_model(model: _T, X: Any, y: Any):
    y_pred = model.predict(X)
    accuracy = accuracy_score(y, y_pred)
    f1 = f1_score(y, y_pred, average='macro')
    precision = precision_score(y, y_pred, average='macro')
    recall = recall_score(y, y_pred, average='macro')
    confusion = confusion_matrix(y, y_pred)
    return namedtuple('Evaluation', ['accuracy', 'f1', 'precision', 'recall', 'confusion'])(accuracy, f1, precision, recall, confusion)

def _get_formatted_metric(values: list[float]):
  avg = sum(values) / len(values)
  std = (sum([(v - avg) ** 2 for v in values]) / len(values)) ** 0.5
  return f"{avg:.4f} ± {std:.4f}"

def train_model(
    model_cls: _T,
    model_kwargs: dict[str, Any],
    train_df: pd.DataFrame,
) -> _T:
    model = model_cls(**model_kwargs)
    model.fit(np.stack(train_df['features'].values), train_df['class'])
    return model

def run_model(
    model_cls: _T,
    model_kwargs: dict[str, Any],
    train_df: pd.DataFrame,
    # val_df: pd.DataFrame,
    test_dfs: dict[str, pd.DataFrame],
    repeat: int = 5,
    transform: str = "color",
    normalize: bool = False
):
  final_res = {
      dataset: {
          'accuracy': [],
          'f1': [],
          'precision': [],
          'recall': [],
      } for dataset in test_dfs.keys()
  }
  training_times = []
  for i in range(repeat):

    _start = time()
    model = train_model(
        model_cls=model_cls,
        model_kwargs=model_kwargs,
        train_df=train_df,
        # val_df=val_df
    )
    _end = time()
    training_times.append(_end - _start)
    for dataset, test_df in test_dfs.items():
      results = evaluate_classic_model(
          model=model,
          X=np.stack(test_df['features'].values),
          y=test_df['class']
      )
      final_res[dataset]['accuracy'].append(results.accuracy)
      final_res[dataset]['f1'].append(results.f1)
      final_res[dataset]['precision'].append(results.precision)
      final_res[dataset]['recall'].append(results.recall)
  print(final_res)
  latex_table = [
    [
      dataset,
      *[_get_formatted_metric(m) for m in metrics.values()]
    ] for dataset, metrics in final_res.items()
  ]
  latex_table_str = ""
  for line in latex_table:
    latex_table_str += " & ".join([str(l) for l in line]) + " \\\\\n"

  return latex_table_str

# %% [markdown]
# # Ray Tune

# %%
import ray
from ray import tune

# %%
def subsample_df(df: pd.DataFrame, frac: float, target_column: str='class') -> pd.DataFrame:
  dfs = []
  for class_name in df[target_column].unique():
    class_df = df[df[target_column] == class_name]
    class_df = class_df.sample(frac=frac)
    dfs.append(class_df)
  return pd.concat(dfs)

# %%
def train_model_tune(
    config,
    model_cls: _T,
    train_df: pd.DataFrame,
    val_df: pd.DataFrame
):
  model = model_cls(**config)

  model.fit(np.stack(train_df['features'].values), train_df['class'])
  val_metrics = evaluate_classic_model(model, np.stack(val_df['features'].values), val_df['class'])

  tune.report(
      {
    "accuracy": val_metrics.accuracy,
    "f1": val_metrics.f1,
    "precision": val_metrics.precision,
    "recall": val_metrics.recall
      }
  )

# %% [markdown]
# # SVC

# %%
tuner = tune.Tuner(
    tune.with_parameters(
        train_model_tune,
        model_cls=LinearSVC,
        train_df=subsample_df(dfs_color['combined']['train'], frac=0.2),
        val_df=dfs_color['combined']['val']
    ),
    param_space={
        "C": tune.grid_search([0.01, 0.1, 0.4, 0.8, 1, 1.2, 2.0, 10]),
    }
)

results = tuner.fit()
# Out:
# 2025-06-07 22:57:42,535	INFO worker.py:1888 -- Started a local Ray instance.
# 2025-06-07 22:57:45,073	INFO tune.py:253 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `Tuner(...)`.
# +-------------------------------------------------------------------------+
# | Configuration for experiment     train_model_tune_2025-06-07_22-57-39   |
# +-------------------------------------------------------------------------+
# | Search algorithm                 BasicVariantGenerator                  |
# | Scheduler                        FIFOScheduler                          |
# | Number of trials                 8                                      |
# +-------------------------------------------------------------------------+
#
# View detailed results here: /root/ray_results/train_model_tune_2025-06-07_22-57-39
# To visualize your results with TensorBoard, run: `tensorboard --logdir /tmp/ray/session_2025-06-07_22-57-39_793194_4490/artifacts/2025-06-07_22-57-45/train_model_tune_2025-06-07_22-57-39/driver_artifacts`
#
# Trial status: 8 PENDING
# Current time: 2025-06-07 22:57:45. Total running time: 0s
# Logical resource usage: 0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                     status         C |
# +-------------------------------------------------+
# | train_model_tune_d3139_00000   PENDING     0.01 |
# | train_model_tune_d3139_00001   PENDING     0.1  |
# | train_model_tune_d3139_00002   PENDING     0.4  |
# | train_model_tune_d3139_00003   PENDING     0.8  |
# | train_model_tune_d3139_00004   PENDING     1    |
# | train_model_tune_d3139_00005   PENDING     1.2  |
# | train_model_tune_d3139_00006   PENDING     2    |
# | train_model_tune_d3139_00007   PENDING    10    |
# +-------------------------------------------------+
#
# Trial train_model_tune_d3139_00000 started with configuration:
# +----------------------------------------------------+
# | Trial train_model_tune_d3139_00000 config          |
# +----------------------------------------------------+
# | C                                             0.01 |
# +----------------------------------------------------+
#
# Trial train_model_tune_d3139_00004 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_d3139_00004 config        |
# +--------------------------------------------------+
# | C                                              1 |
# +--------------------------------------------------+
#
# Trial train_model_tune_d3139_00005 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_d3139_00005 config         |
# +---------------------------------------------------+
# | C                                             1.2 |
# +---------------------------------------------------+
#
# Trial train_model_tune_d3139_00002 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_d3139_00002 config         |
# +---------------------------------------------------+
# | C                                             0.4 |
# +---------------------------------------------------+
#
# Trial train_model_tune_d3139_00003 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_d3139_00003 config         |
# +---------------------------------------------------+
# | C                                             0.8 |
# +---------------------------------------------------+
#
# Trial train_model_tune_d3139_00001 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_d3139_00001 config         |
# +---------------------------------------------------+
# | C                                             0.1 |
# +---------------------------------------------------+
#
# Trial train_model_tune_d3139_00007 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_d3139_00007 config        |
# +--------------------------------------------------+
# | C                                             10 |
# +--------------------------------------------------+
#
# Trial train_model_tune_d3139_00006 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_d3139_00006 config        |
# +--------------------------------------------------+
# | C                                              2 |
# +--------------------------------------------------+
#
# Trial status: 8 RUNNING
# Current time: 2025-06-07 22:58:15. Total running time: 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                     status         C |
# +-------------------------------------------------+
# | train_model_tune_d3139_00000   RUNNING     0.01 |
# | train_model_tune_d3139_00001   RUNNING     0.1  |
# | train_model_tune_d3139_00002   RUNNING     0.4  |
# | train_model_tune_d3139_00003   RUNNING     0.8  |
# | train_model_tune_d3139_00004   RUNNING     1    |
# | train_model_tune_d3139_00005   RUNNING     1.2  |
# | train_model_tune_d3139_00006   RUNNING     2    |
# | train_model_tune_d3139_00007   RUNNING    10    |
# +-------------------------------------------------+
# Trial status: 8 RUNNING
# Current time: 2025-06-07 22:58:45. Total running time: 1min 0s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                     status         C |
# +-------------------------------------------------+
# | train_model_tune_d3139_00000   RUNNING     0.01 |
# | train_model_tune_d3139_00001   RUNNING     0.1  |
# | train_model_tune_d3139_00002   RUNNING     0.4  |
# | train_model_tune_d3139_00003   RUNNING     0.8  |
# | train_model_tune_d3139_00004   RUNNING     1    |
# | train_model_tune_d3139_00005   RUNNING     1.2  |
# | train_model_tune_d3139_00006   RUNNING     2    |
# | train_model_tune_d3139_00007   RUNNING    10    |
# +-------------------------------------------------+
# Trial status: 8 RUNNING
# Current time: 2025-06-07 22:59:16. Total running time: 1min 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                     status         C |
# +-------------------------------------------------+
# | train_model_tune_d3139_00000   RUNNING     0.01 |
# | train_model_tune_d3139_00001   RUNNING     0.1  |
# | train_model_tune_d3139_00002   RUNNING     0.4  |
# | train_model_tune_d3139_00003   RUNNING     0.8  |
# | train_model_tune_d3139_00004   RUNNING     1    |
# | train_model_tune_d3139_00005   RUNNING     1.2  |
# | train_model_tune_d3139_00006   RUNNING     2    |
# | train_model_tune_d3139_00007   RUNNING    10    |
# +-------------------------------------------------+
# Trial status: 8 RUNNING
# Current time: 2025-06-07 22:59:46. Total running time: 2min 0s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                     status         C |
# +-------------------------------------------------+
# | train_model_tune_d3139_00000   RUNNING     0.01 |
# | train_model_tune_d3139_00001   RUNNING     0.1  |
# | train_model_tune_d3139_00002   RUNNING     0.4  |
# | train_model_tune_d3139_00003   RUNNING     0.8  |
# | train_model_tune_d3139_00004   RUNNING     1    |
# | train_model_tune_d3139_00005   RUNNING     1.2  |
# | train_model_tune_d3139_00006   RUNNING     2    |
# | train_model_tune_d3139_00007   RUNNING    10    |
# +-------------------------------------------------+
# Trial status: 8 RUNNING
# Current time: 2025-06-07 23:00:16. Total running time: 2min 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                     status         C |
# +-------------------------------------------------+
# | train_model_tune_d3139_00000   RUNNING     0.01 |
# | train_model_tune_d3139_00001   RUNNING     0.1  |
# | train_model_tune_d3139_00002   RUNNING     0.4  |
# | train_model_tune_d3139_00003   RUNNING     0.8  |
# | train_model_tune_d3139_00004   RUNNING     1    |
# | train_model_tune_d3139_00005   RUNNING     1.2  |
# | train_model_tune_d3139_00006   RUNNING     2    |
# | train_model_tune_d3139_00007   RUNNING    10    |
# +-------------------------------------------------+
# Trial status: 8 RUNNING
# Current time: 2025-06-07 23:00:46. Total running time: 3min 0s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                     status         C |
# +-------------------------------------------------+
# | train_model_tune_d3139_00000   RUNNING     0.01 |
# | train_model_tune_d3139_00001   RUNNING     0.1  |
# | train_model_tune_d3139_00002   RUNNING     0.4  |
# | train_model_tune_d3139_00003   RUNNING     0.8  |
# | train_model_tune_d3139_00004   RUNNING     1    |
# | train_model_tune_d3139_00005   RUNNING     1.2  |
# | train_model_tune_d3139_00006   RUNNING     2    |
# | train_model_tune_d3139_00007   RUNNING    10    |
# +-------------------------------------------------+
# Trial status: 8 RUNNING
# Current time: 2025-06-07 23:01:16. Total running time: 3min 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                     status         C |
# +-------------------------------------------------+
# | train_model_tune_d3139_00000   RUNNING     0.01 |
# | train_model_tune_d3139_00001   RUNNING     0.1  |
# | train_model_tune_d3139_00002   RUNNING     0.4  |
# | train_model_tune_d3139_00003   RUNNING     0.8  |
# | train_model_tune_d3139_00004   RUNNING     1    |
# | train_model_tune_d3139_00005   RUNNING     1.2  |
# | train_model_tune_d3139_00006   RUNNING     2    |
# | train_model_tune_d3139_00007   RUNNING    10    |
# +-------------------------------------------------+
# Trial status: 8 RUNNING
# Current time: 2025-06-07 23:01:46. Total running time: 4min 0s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                     status         C |
# +-------------------------------------------------+
# | train_model_tune_d3139_00000   RUNNING     0.01 |
# | train_model_tune_d3139_00001   RUNNING     0.1  |
# | train_model_tune_d3139_00002   RUNNING     0.4  |
# | train_model_tune_d3139_00003   RUNNING     0.8  |
# | train_model_tune_d3139_00004   RUNNING     1    |
# | train_model_tune_d3139_00005   RUNNING     1.2  |
# | train_model_tune_d3139_00006   RUNNING     2    |
# | train_model_tune_d3139_00007   RUNNING    10    |
# +-------------------------------------------------+
# Trial status: 8 RUNNING
# Current time: 2025-06-07 23:02:16. Total running time: 4min 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                     status         C |
# +-------------------------------------------------+
# | train_model_tune_d3139_00000   RUNNING     0.01 |
# | train_model_tune_d3139_00001   RUNNING     0.1  |
# | train_model_tune_d3139_00002   RUNNING     0.4  |
# | train_model_tune_d3139_00003   RUNNING     0.8  |
# | train_model_tune_d3139_00004   RUNNING     1    |
# | train_model_tune_d3139_00005   RUNNING     1.2  |
# | train_model_tune_d3139_00006   RUNNING     2    |
# | train_model_tune_d3139_00007   RUNNING    10    |
# +-------------------------------------------------+
# Trial status: 8 RUNNING
# Current time: 2025-06-07 23:02:46. Total running time: 5min 0s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                     status         C |
# +-------------------------------------------------+
# | train_model_tune_d3139_00000   RUNNING     0.01 |
# | train_model_tune_d3139_00001   RUNNING     0.1  |
# | train_model_tune_d3139_00002   RUNNING     0.4  |
# | train_model_tune_d3139_00003   RUNNING     0.8  |
# | train_model_tune_d3139_00004   RUNNING     1    |
# | train_model_tune_d3139_00005   RUNNING     1.2  |
# | train_model_tune_d3139_00006   RUNNING     2    |
# | train_model_tune_d3139_00007   RUNNING    10    |
# +-------------------------------------------------+
# Trial status: 8 RUNNING
# Current time: 2025-06-07 23:03:16. Total running time: 5min 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                     status         C |
# +-------------------------------------------------+
# | train_model_tune_d3139_00000   RUNNING     0.01 |
# | train_model_tune_d3139_00001   RUNNING     0.1  |
# | train_model_tune_d3139_00002   RUNNING     0.4  |
# | train_model_tune_d3139_00003   RUNNING     0.8  |
# | train_model_tune_d3139_00004   RUNNING     1    |
# | train_model_tune_d3139_00005   RUNNING     1.2  |
# | train_model_tune_d3139_00006   RUNNING     2    |
# | train_model_tune_d3139_00007   RUNNING    10    |
# +-------------------------------------------------+
# Trial status: 8 RUNNING
# Current time: 2025-06-07 23:03:46. Total running time: 6min 0s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                     status         C |
# +-------------------------------------------------+
# | train_model_tune_d3139_00000   RUNNING     0.01 |
# | train_model_tune_d3139_00001   RUNNING     0.1  |
# | train_model_tune_d3139_00002   RUNNING     0.4  |
# | train_model_tune_d3139_00003   RUNNING     0.8  |
# | train_model_tune_d3139_00004   RUNNING     1    |
# | train_model_tune_d3139_00005   RUNNING     1.2  |
# | train_model_tune_d3139_00006   RUNNING     2    |
# | train_model_tune_d3139_00007   RUNNING    10    |
# +-------------------------------------------------+
# Trial status: 8 RUNNING
# Current time: 2025-06-07 23:04:16. Total running time: 6min 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                     status         C |
# +-------------------------------------------------+
# | train_model_tune_d3139_00000   RUNNING     0.01 |
# | train_model_tune_d3139_00001   RUNNING     0.1  |
# | train_model_tune_d3139_00002   RUNNING     0.4  |
# | train_model_tune_d3139_00003   RUNNING     0.8  |
# | train_model_tune_d3139_00004   RUNNING     1    |
# | train_model_tune_d3139_00005   RUNNING     1.2  |
# | train_model_tune_d3139_00006   RUNNING     2    |
# | train_model_tune_d3139_00007   RUNNING    10    |
# +-------------------------------------------------+
# Trial status: 8 RUNNING
# Current time: 2025-06-07 23:04:46. Total running time: 7min 0s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                     status         C |
# +-------------------------------------------------+
# | train_model_tune_d3139_00000   RUNNING     0.01 |
# | train_model_tune_d3139_00001   RUNNING     0.1  |
# | train_model_tune_d3139_00002   RUNNING     0.4  |
# | train_model_tune_d3139_00003   RUNNING     0.8  |
# | train_model_tune_d3139_00004   RUNNING     1    |
# | train_model_tune_d3139_00005   RUNNING     1.2  |
# | train_model_tune_d3139_00006   RUNNING     2    |
# | train_model_tune_d3139_00007   RUNNING    10    |
# +-------------------------------------------------+
# Trial status: 8 RUNNING
# Current time: 2025-06-07 23:05:16. Total running time: 7min 31s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                     status         C |
# +-------------------------------------------------+
# | train_model_tune_d3139_00000   RUNNING     0.01 |
# | train_model_tune_d3139_00001   RUNNING     0.1  |
# | train_model_tune_d3139_00002   RUNNING     0.4  |
# | train_model_tune_d3139_00003   RUNNING     0.8  |
# | train_model_tune_d3139_00004   RUNNING     1    |
# | train_model_tune_d3139_00005   RUNNING     1.2  |
# | train_model_tune_d3139_00006   RUNNING     2    |
# | train_model_tune_d3139_00007   RUNNING    10    |
# +-------------------------------------------------+
# Trial status: 8 RUNNING
# Current time: 2025-06-07 23:05:46. Total running time: 8min 1s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------+
# | Trial name                     status         C |
# +-------------------------------------------------+
# | train_model_tune_d3139_00000   RUNNING     0.01 |
# | train_model_tune_d3139_00001   RUNNING     0.1  |
# | train_model_tune_d3139_00002   RUNNING     0.4  |
# | train_model_tune_d3139_00003   RUNNING     0.8  |
# | train_model_tune_d3139_00004   RUNNING     1    |
# | train_model_tune_d3139_00005   RUNNING     1.2  |
# | train_model_tune_d3139_00006   RUNNING     2    |
# | train_model_tune_d3139_00007   RUNNING    10    |
# +-------------------------------------------------+
# (train_model_tune pid=7222) /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
# (train_model_tune pid=7222)   warnings.warn(
# Trial train_model_tune_d3139_00005 completed after 1 iterations at 2025-06-07 23:06:06. Total running time: 8min 21s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3139_00005 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              495.958 |
# | time_total_s                                  495.958 |
# | training_iteration                                  1 |
# | accuracy                                      0.66921 |
# | f1                                            0.64775 |
# | precision                                     0.69764 |
# | recall                                        0.65882 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3139_00004 completed after 1 iterations at 2025-06-07 23:06:08. Total running time: 8min 22s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3139_00004 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              497.538 |
# | time_total_s                                  497.538 |
# | training_iteration                                  1 |
# | accuracy                                      0.67176 |
# | f1                                            0.64903 |
# | precision                                     0.70387 |
# | recall                                          0.661 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3139_00006 completed after 1 iterations at 2025-06-07 23:06:08. Total running time: 8min 22s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3139_00006 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              497.254 |
# | time_total_s                                  497.254 |
# | training_iteration                                  1 |
# | accuracy                                      0.66921 |
# | f1                                             0.6394 |
# | precision                                     0.71656 |
# | recall                                        0.65685 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3139_00002 completed after 1 iterations at 2025-06-07 23:06:09. Total running time: 8min 23s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3139_00002 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              498.047 |
# | time_total_s                                  498.047 |
# | training_iteration                                  1 |
# | accuracy                                      0.66667 |
# | f1                                            0.64551 |
# | precision                                     0.69353 |
# | recall                                        0.65639 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3139_00003 completed after 1 iterations at 2025-06-07 23:06:09. Total running time: 8min 23s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3139_00003 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                               498.04 |
# | time_total_s                                   498.04 |
# | training_iteration                                  1 |
# | accuracy                                      0.66667 |
# | f1                                            0.64359 |
# | precision                                     0.69741 |
# | recall                                         0.6559 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3139_00007 completed after 1 iterations at 2025-06-07 23:06:09. Total running time: 8min 23s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3139_00007 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              498.362 |
# | time_total_s                                  498.362 |
# | training_iteration                                  1 |
# | accuracy                                      0.66921 |
# | f1                                            0.64582 |
# | precision                                     0.70169 |
# | recall                                        0.65833 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3139_00001 completed after 1 iterations at 2025-06-07 23:06:09. Total running time: 8min 24s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3139_00001 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              498.703 |
# | time_total_s                                  498.703 |
# | training_iteration                                  1 |
# | accuracy                                      0.67176 |
# | f1                                            0.64999 |
# | precision                                      0.7018 |
# | recall                                        0.66125 |
# +-------------------------------------------------------+
# (train_model_tune pid=7224) /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations. [repeated 7x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (train_model_tune pid=7224)   warnings.warn( [repeated 7x across cluster]
# 2025-06-07 23:06:12,486	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/root/ray_results/train_model_tune_2025-06-07_22-57-39' in 0.0068s.
# Trial train_model_tune_d3139_00000 completed after 1 iterations at 2025-06-07 23:06:12. Total running time: 8min 26s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3139_00000 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              501.665 |
# | time_total_s                                  501.665 |
# | training_iteration                                  1 |
# | accuracy                                      0.68448 |
# | f1                                            0.66022 |
# | precision                                     0.72615 |
# | recall                                        0.67313 |
# +-------------------------------------------------------+
#
# Trial status: 8 TERMINATED
# Current time: 2025-06-07 23:06:12. Total running time: 8min 26s
# Logical resource usage: 1.0/8 CPUs, 0/0 GPUs
# +--------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status           C     iter     total time (s)     accuracy         f1     precision     recall |
# +--------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_d3139_00000   TERMINATED    0.01        1            501.665     0.684478   0.660224      0.726146   0.673135 |
# | train_model_tune_d3139_00001   TERMINATED    0.1         1            498.703     0.671756   0.649991      0.701803   0.661246 |
# | train_model_tune_d3139_00002   TERMINATED    0.4         1            498.047     0.666667   0.645514      0.693527   0.656391 |
# | train_model_tune_d3139_00003   TERMINATED    0.8         1            498.04      0.666667   0.64359       0.697406   0.655898 |
# | train_model_tune_d3139_00004   TERMINATED    1           1            497.538     0.671756   0.649032      0.703866   0.660999 |
# | train_model_tune_d3139_00005   TERMINATED    1.2         1            495.958     0.669211   0.647752      0.697635   0.658818 |
# | train_model_tune_d3139_00006   TERMINATED    2           1            497.254     0.669211   0.639399      0.716559   0.656845 |
# | train_model_tune_d3139_00007   TERMINATED   10           1            498.362     0.669211   0.645818      0.701687   0.658325 |
# +--------------------------------------------------------------------------------------------------------------------------------+

# %%
best_results = results.get_best_result(metric='f1', mode='max')
best_results.config
# Out:
# {'C': 0.01}

# %%
best_results = results.get_best_result(metric='f1', mode='max')

run_model(
    model_cls=LinearSVC,
    model_kwargs=best_results.config,
    train_df=dfs_color['combined']['train'],
    test_dfs={dataset: dfs_color[dataset]['test'] for dataset in dfs_color.keys()},
    repeat=5
)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# {'fog-detection': {'accuracy': [0.8113207547169812, 0.7924528301886793, 0.7830188679245284, 0.8113207547169812, 0.7924528301886793], 'f1': [0.7720430107526881, 0.744298245614035, 0.7299213470699014, 0.7720430107526881, 0.744298245614035], 'precision': [0.8823529411764706, 0.8735632183908046, 0.8693181818181819, 0.8823529411764706, 0.8735632183908046], 'recall': [0.7560975609756098, 0.7317073170731707, 0.7195121951219512, 0.7560975609756098, 0.7317073170731707]}, 'foggy-cityscapes': {'accuracy': [0.5858585858585859, 0.5858585858585859, 0.5909090909090909, 0.5909090909090909, 0.5858585858585859], 'f1': [0.5716999050332383, 0.570021186440678, 0.5761067794370291, 0.5806291347436132, 0.5716999050332383], 'precision': [0.5989417989417989, 0.60069402895776, 0.605668880455408, 0.6007918552036199, 0.5989417989417989], 'recall': [0.5858585858585859, 0.5858585858585859, 0.5909090909090909, 0.5909090909090909, 0.5858585858585859]}, 'fog-or-smog': {'accuracy': [0.8103448275862069, 0.8103448275862069, 0.8081896551724138, 0.8103448275862069, 0.8125], 'f1': [0.8051164566628484, 0.8048295508861825, 0.8024634665518644, 0.8053951005623868, 0.8071902448809984], 'precision': [0.8339837398373984, 0.835704357779413, 0.8342147879384212, 0.8323360556319237, 0.8371991113466359], 'recall': [0.8056547619047618, 0.8055059523809524, 0.8032738095238094, 0.8058035714285714, 0.8077380952380953]}, 'combined': {'accuracy': [0.7526041666666666, 0.75, 0.7486979166666666, 0.75390625, 0.7513020833333334], 'f1': [0.7419573890162126, 0.7383583519642287, 0.7368438806579614, 0.744280975224753, 0.7401650538577221], 'precision': [0.778287841191067, 0.7784464066869874, 0.7774807687765242, 0.7763444559110193, 0.7783470558395442], 'recall': [0.7440430856272441, 0.741023827657491, 0.7396502012838646, 0.7458247198346208, 0.7425334566423676]}}
# 'fog-detection & 0.7981 ± 0.0113 & 0.7525 ± 0.0168 & 0.8762 ± 0.0052 & 0.7390 ± 0.0146 \\\\\nfoggy-cityscapes & 0.5879 ± 0.0025 & 0.5740 ± 0.0039 & 0.6010 ± 0.0025 & 0.5879 ± 0.0025 \\\\\nfog-or-smog & 0.8103 ± 0.0014 & 0.8050 ± 0.0015 & 0.8347 ± 0.0016 & 0.8056 ± 0.0014 \\\\\ncombined & 0.7513 ± 0.0018 & 0.7403 ± 0.0026 & 0.7778 ± 0.0008 & 0.7426 ± 0.0022 \\\\\n'

# %% [markdown]
# # RFC

# %%
tuner = tune.Tuner(
    tune.with_parameters(
        train_model_tune,
        model_cls=RandomForestClassifier,
        # train_df=dfs_color['combined']['train'],
        train_df=subsample_df(dfs_color['combined']['train'], frac=0.2),
        val_df=dfs_color['combined']['val']
    ),
    param_space={
        "n_estimators": tune.grid_search([10, 50, 100, 200]),
        "max_depth": tune.grid_search([1, 5, 10, 20, 50, None]),
    }
)

results = tuner.fit()
# Out:
# +-------------------------------------------------------------------------+
# | Configuration for experiment     train_model_tune_2025-06-08_00-59-27   |
# +-------------------------------------------------------------------------+
# | Search algorithm                 BasicVariantGenerator                  |
# | Scheduler                        FIFOScheduler                          |
# | Number of trials                 24                                     |
# +-------------------------------------------------------------------------+
#
# View detailed results here: /root/ray_results/train_model_tune_2025-06-08_00-59-27
# To visualize your results with TensorBoard, run: `tensorboard --logdir /tmp/ray/session_2025-06-07_22-57-39_793194_4490/artifacts/2025-06-08_00-59-27/train_model_tune_2025-06-08_00-59-27/driver_artifacts`
#
# Trial status: 24 PENDING
# Current time: 2025-06-08 00:59:28. Total running time: 0s
# Logical resource usage: 0/8 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------+
# | Trial name                     status       n_estimators     max_depth |
# +------------------------------------------------------------------------+
# | train_model_tune_d3e99_00000   PENDING                10             1 |
# | train_model_tune_d3e99_00001   PENDING                10             5 |
# | train_model_tune_d3e99_00002   PENDING                10            10 |
# | train_model_tune_d3e99_00003   PENDING                10            20 |
# | train_model_tune_d3e99_00004   PENDING                10            50 |
# +------------------------------------------------------------------------+
# 19 more PENDING
#
# Trial train_model_tune_d3e99_00002 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_d3e99_00002 config        |
# +--------------------------------------------------+
# | max_depth                                     10 |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial train_model_tune_d3e99_00003 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_d3e99_00003 config        |
# +--------------------------------------------------+
# | max_depth                                     20 |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial train_model_tune_d3e99_00007 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_d3e99_00007 config        |
# +--------------------------------------------------+
# | max_depth                                      5 |
# | n_estimators                                  50 |
# +--------------------------------------------------+
#
# Trial train_model_tune_d3e99_00004 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_d3e99_00004 config        |
# +--------------------------------------------------+
# | max_depth                                     50 |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial train_model_tune_d3e99_00001 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_d3e99_00001 config        |
# +--------------------------------------------------+
# | max_depth                                      5 |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial train_model_tune_d3e99_00006 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_d3e99_00006 config        |
# +--------------------------------------------------+
# | max_depth                                      1 |
# | n_estimators                                  50 |
# +--------------------------------------------------+
#
# Trial train_model_tune_d3e99_00005 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_d3e99_00005 config        |
# +--------------------------------------------------+
# | max_depth                                        |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial train_model_tune_d3e99_00000 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_d3e99_00000 config        |
# +--------------------------------------------------+
# | max_depth                                      1 |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial train_model_tune_d3e99_00000 completed after 1 iterations at 2025-06-08 00:59:35. Total running time: 7s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00000 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              1.08724 |
# | time_total_s                                  1.08724 |
# | training_iteration                                  1 |
# | accuracy                                       0.6972 |
# | f1                                             0.6937 |
# | precision                                     0.69864 |
# | recall                                        0.69366 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3e99_00001 completed after 1 iterations at 2025-06-08 00:59:36. Total running time: 8s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00001 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                               2.1174 |
# | time_total_s                                   2.1174 |
# | training_iteration                                  1 |
# | accuracy                                      0.75318 |
# | f1                                            0.75226 |
# | precision                                     0.75277 |
# | recall                                        0.75199 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3e99_00006 completed after 1 iterations at 2025-06-08 00:59:36. Total running time: 9s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00006 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              2.41979 |
# | time_total_s                                  2.41979 |
# | training_iteration                                  1 |
# | accuracy                                       0.6972 |
# | f1                                             0.6937 |
# | precision                                     0.69864 |
# | recall                                        0.69366 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3e99_00003 completed after 1 iterations at 2025-06-08 00:59:37. Total running time: 9s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00003 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                               2.7553 |
# | time_total_s                                   2.7553 |
# | training_iteration                                  1 |
# | accuracy                                      0.77608 |
# | f1                                            0.77584 |
# | precision                                     0.77574 |
# | recall                                         0.7763 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3e99_00002 completed after 1 iterations at 2025-06-08 00:59:37. Total running time: 9s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00002 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              2.77477 |
# | time_total_s                                  2.77477 |
# | training_iteration                                  1 |
# | accuracy                                      0.79644 |
# | f1                                            0.79628 |
# | precision                                     0.79627 |
# | recall                                        0.79695 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3e99_00005 completed after 1 iterations at 2025-06-08 00:59:37. Total running time: 9s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00005 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              2.79809 |
# | time_total_s                                  2.79809 |
# | training_iteration                                  1 |
# | accuracy                                      0.76336 |
# | f1                                            0.76321 |
# | precision                                      0.7633 |
# | recall                                        0.76391 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3e99_00004 completed after 1 iterations at 2025-06-08 00:59:37. Total running time: 9s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00004 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              2.86843 |
# | time_total_s                                  2.86843 |
# | training_iteration                                  1 |
# | accuracy                                      0.79135 |
# | f1                                            0.79134 |
# | precision                                     0.79408 |
# | recall                                        0.79357 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3e99_00008 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_d3e99_00008 config        |
# +--------------------------------------------------+
# | max_depth                                     10 |
# | n_estimators                                  50 |
# +--------------------------------------------------+
#
# Trial train_model_tune_d3e99_00007 completed after 1 iterations at 2025-06-08 00:59:42. Total running time: 14s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00007 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              7.79066 |
# | time_total_s                                  7.79066 |
# | training_iteration                                  1 |
# | accuracy                                       0.7888 |
# | f1                                            0.78814 |
# | precision                                     0.78843 |
# | recall                                        0.78794 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3e99_00010 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_d3e99_00010 config        |
# +--------------------------------------------------+
# | max_depth                                     50 |
# | n_estimators                                  50 |
# +--------------------------------------------------+
#
# Trial train_model_tune_d3e99_00009 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_d3e99_00009 config        |
# +--------------------------------------------------+
# | max_depth                                     20 |
# | n_estimators                                  50 |
# +--------------------------------------------------+
#
# Trial train_model_tune_d3e99_00012 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_d3e99_00012 config         |
# +---------------------------------------------------+
# | max_depth                                       1 |
# | n_estimators                                  100 |
# +---------------------------------------------------+
#
# Trial train_model_tune_d3e99_00011 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_d3e99_00011 config        |
# +--------------------------------------------------+
# | max_depth                                        |
# | n_estimators                                  50 |
# +--------------------------------------------------+
#
# Trial train_model_tune_d3e99_00013 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_d3e99_00013 config         |
# +---------------------------------------------------+
# | max_depth                                       5 |
# | n_estimators                                  100 |
# +---------------------------------------------------+
#
# Trial train_model_tune_d3e99_00014 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_d3e99_00014 config         |
# +---------------------------------------------------+
# | max_depth                                      10 |
# | n_estimators                                  100 |
# +---------------------------------------------------+
#
# Trial train_model_tune_d3e99_00012 completed after 1 iterations at 2025-06-08 00:59:47. Total running time: 19s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00012 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                                4.528 |
# | time_total_s                                    4.528 |
# | training_iteration                                  1 |
# | accuracy                                      0.69211 |
# | f1                                            0.68855 |
# | precision                                      0.6934 |
# | recall                                        0.68855 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3e99_00015 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_d3e99_00015 config         |
# +---------------------------------------------------+
# | max_depth                                      20 |
# | n_estimators                                  100 |
# +---------------------------------------------------+
#
# Trial train_model_tune_d3e99_00016 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_d3e99_00016 config         |
# +---------------------------------------------------+
# | max_depth                                      50 |
# | n_estimators                                  100 |
# +---------------------------------------------------+
#
# Trial train_model_tune_d3e99_00008 completed after 1 iterations at 2025-06-08 00:59:53. Total running time: 25s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00008 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              11.5381 |
# | time_total_s                                  11.5381 |
# | training_iteration                                  1 |
# | accuracy                                       0.8117 |
# | f1                                            0.81156 |
# | precision                                     0.81154 |
# | recall                                        0.81225 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3e99_00010 completed after 1 iterations at 2025-06-08 00:59:53. Total running time: 25s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00010 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              11.2941 |
# | time_total_s                                  11.2941 |
# | training_iteration                                  1 |
# | accuracy                                      0.81425 |
# | f1                                            0.81421 |
# | precision                                     0.81478 |
# | recall                                        0.81542 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3e99_00009 completed after 1 iterations at 2025-06-08 00:59:54. Total running time: 26s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00009 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              11.6028 |
# | time_total_s                                  11.6028 |
# | training_iteration                                  1 |
# | accuracy                                      0.80153 |
# | f1                                            0.80137 |
# | precision                                     0.80136 |
# | recall                                        0.80205 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3e99_00011 completed after 1 iterations at 2025-06-08 00:59:54. Total running time: 26s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00011 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              11.5567 |
# | time_total_s                                  11.5567 |
# | training_iteration                                  1 |
# | accuracy                                      0.80407 |
# | f1                                            0.80394 |
# | precision                                     0.80401 |
# | recall                                        0.80472 |
# +-------------------------------------------------------+
#
# Trial status: 13 TERMINATED | 4 RUNNING | 7 PENDING
# Current time: 2025-06-08 00:59:58. Total running time: 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_d3e99_00013   RUNNING                 100             5                                                                              |
# | train_model_tune_d3e99_00014   RUNNING                 100            10                                                                              |
# | train_model_tune_d3e99_00015   RUNNING                 100            20                                                                              |
# | train_model_tune_d3e99_00016   RUNNING                 100            50                                                                              |
# | train_model_tune_d3e99_00000   TERMINATED               10             1        1            1.08724     0.697201   0.693703      0.698637   0.693656 |
# | train_model_tune_d3e99_00001   TERMINATED               10             5        1            2.1174      0.753181   0.752257      0.752773   0.751986 |
# | train_model_tune_d3e99_00002   TERMINATED               10            10        1            2.77477     0.796438   0.796278      0.79627    0.796947 |
# | train_model_tune_d3e99_00003   TERMINATED               10            20        1            2.7553      0.776081   0.775836      0.775738   0.776297 |
# | train_model_tune_d3e99_00004   TERMINATED               10            50        1            2.86843     0.791349   0.791336      0.794076   0.793573 |
# | train_model_tune_d3e99_00017   PENDING                 100                                                                                            |
# | train_model_tune_d3e99_00018   PENDING                 200             1                                                                              |
# | train_model_tune_d3e99_00019   PENDING                 200             5                                                                              |
# | train_model_tune_d3e99_00020   PENDING                 200            10                                                                              |
# | train_model_tune_d3e99_00021   PENDING                 200            20                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 8 more TERMINATED, 2 more PENDING
#
# Trial train_model_tune_d3e99_00017 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_d3e99_00017 config         |
# +---------------------------------------------------+
# | max_depth                                         |
# | n_estimators                                  100 |
# +---------------------------------------------------+
#
# Trial train_model_tune_d3e99_00013 completed after 1 iterations at 2025-06-08 00:59:58. Total running time: 30s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00013 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              15.1177 |
# | time_total_s                                  15.1177 |
# | training_iteration                                  1 |
# | accuracy                                      0.78372 |
# | f1                                            0.78291 |
# | precision                                     0.78347 |
# | recall                                        0.78259 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3e99_00019 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_d3e99_00019 config         |
# +---------------------------------------------------+
# | max_depth                                       5 |
# | n_estimators                                  200 |
# +---------------------------------------------------+
#
# Trial train_model_tune_d3e99_00018 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_d3e99_00018 config         |
# +---------------------------------------------------+
# | max_depth                                       1 |
# | n_estimators                                  200 |
# +---------------------------------------------------+
#
# Trial train_model_tune_d3e99_00020 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_d3e99_00020 config         |
# +---------------------------------------------------+
# | max_depth                                      10 |
# | n_estimators                                  200 |
# +---------------------------------------------------+
#
# Trial train_model_tune_d3e99_00021 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_d3e99_00021 config         |
# +---------------------------------------------------+
# | max_depth                                      20 |
# | n_estimators                                  200 |
# +---------------------------------------------------+
#
# Trial train_model_tune_d3e99_00014 completed after 1 iterations at 2025-06-08 01:00:05. Total running time: 37s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00014 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              22.1244 |
# | time_total_s                                  22.1244 |
# | training_iteration                                  1 |
# | accuracy                                      0.80916 |
# | f1                                            0.80892 |
# | precision                                     0.80877 |
# | recall                                        0.80933 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3e99_00018 completed after 1 iterations at 2025-06-08 01:00:07. Total running time: 39s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00018 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              8.09925 |
# | time_total_s                                  8.09925 |
# | training_iteration                                  1 |
# | accuracy                                      0.69975 |
# | f1                                            0.69644 |
# | precision                                     0.70104 |
# | recall                                        0.69633 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3e99_00015 completed after 1 iterations at 2025-06-08 01:00:11. Total running time: 43s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00015 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              22.0612 |
# | time_total_s                                  22.0612 |
# | training_iteration                                  1 |
# | accuracy                                      0.80407 |
# | f1                                            0.80389 |
# | precision                                     0.80381 |
# | recall                                        0.80448 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3e99_00022 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_d3e99_00022 config         |
# +---------------------------------------------------+
# | max_depth                                      50 |
# | n_estimators                                  200 |
# +---------------------------------------------------+
#
# Trial train_model_tune_d3e99_00023 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_d3e99_00023 config         |
# +---------------------------------------------------+
# | max_depth                                         |
# | n_estimators                                  200 |
# +---------------------------------------------------+
#
# Trial train_model_tune_d3e99_00016 completed after 1 iterations at 2025-06-08 01:00:14. Total running time: 46s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00016 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              22.2225 |
# | time_total_s                                  22.2225 |
# | training_iteration                                  1 |
# | accuracy                                      0.80153 |
# | f1                                            0.80137 |
# | precision                                     0.80136 |
# | recall                                        0.80205 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3e99_00017 completed after 1 iterations at 2025-06-08 01:00:19. Total running time: 51s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00017 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                               20.851 |
# | time_total_s                                   20.851 |
# | training_iteration                                  1 |
# | accuracy                                      0.81679 |
# | f1                                            0.81674 |
# | precision                                     0.81715 |
# | recall                                        0.81784 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3e99_00019 completed after 1 iterations at 2025-06-08 01:00:26. Total running time: 58s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00019 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              27.2061 |
# | time_total_s                                  27.2061 |
# | training_iteration                                  1 |
# | accuracy                                      0.78117 |
# | f1                                            0.78028 |
# | precision                                     0.78101 |
# | recall                                        0.77992 |
# +-------------------------------------------------------+
#
# Trial status: 20 TERMINATED | 4 RUNNING
# Current time: 2025-06-08 01:00:28. Total running time: 1min 0s
# Logical resource usage: 4.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_d3e99_00020   RUNNING                 200            10                                                                              |
# | train_model_tune_d3e99_00021   RUNNING                 200            20                                                                              |
# | train_model_tune_d3e99_00022   RUNNING                 200            50                                                                              |
# | train_model_tune_d3e99_00023   RUNNING                 200                                                                                            |
# | train_model_tune_d3e99_00000   TERMINATED               10             1        1            1.08724     0.697201   0.693703      0.698637   0.693656 |
# | train_model_tune_d3e99_00001   TERMINATED               10             5        1            2.1174      0.753181   0.752257      0.752773   0.751986 |
# | train_model_tune_d3e99_00002   TERMINATED               10            10        1            2.77477     0.796438   0.796278      0.79627    0.796947 |
# | train_model_tune_d3e99_00003   TERMINATED               10            20        1            2.7553      0.776081   0.775836      0.775738   0.776297 |
# | train_model_tune_d3e99_00004   TERMINATED               10            50        1            2.86843     0.791349   0.791336      0.794076   0.793573 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 15 more TERMINATED
#
# Trial train_model_tune_d3e99_00020 completed after 1 iterations at 2025-06-08 01:00:36. Total running time: 1min 8s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00020 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              36.8023 |
# | time_total_s                                  36.8023 |
# | training_iteration                                  1 |
# | accuracy                                      0.81679 |
# | f1                                            0.81665 |
# | precision                                     0.81663 |
# | recall                                        0.81735 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3e99_00021 completed after 1 iterations at 2025-06-08 01:00:40. Total running time: 1min 12s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00021 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              35.8436 |
# | time_total_s                                  35.8436 |
# | training_iteration                                  1 |
# | accuracy                                      0.82697 |
# | f1                                            0.82688 |
# | precision                                     0.82704 |
# | recall                                         0.8278 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_d3e99_00022 completed after 1 iterations at 2025-06-08 01:00:46. Total running time: 1min 18s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00022 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              34.8006 |
# | time_total_s                                  34.8006 |
# | training_iteration                                  1 |
# | accuracy                                      0.81679 |
# | f1                                             0.8167 |
# | precision                                     0.81686 |
# | recall                                         0.8176 |
# +-------------------------------------------------------+
# 2025-06-08 01:00:46,859	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/root/ray_results/train_model_tune_2025-06-08_00-59-27' in 0.0120s.
# Trial train_model_tune_d3e99_00023 completed after 1 iterations at 2025-06-08 01:00:46. Total running time: 1min 18s
# +-------------------------------------------------------+
# | Trial train_model_tune_d3e99_00023 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              34.4792 |
# | time_total_s                                  34.4792 |
# | training_iteration                                  1 |
# | accuracy                                      0.82952 |
# | f1                                            0.82936 |
# | precision                                     0.82926 |
# | recall                                        0.82998 |
# +-------------------------------------------------------+
#
# Trial status: 24 TERMINATED
# Current time: 2025-06-08 01:00:46. Total running time: 1min 18s
# Logical resource usage: 1.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_d3e99_00000   TERMINATED               10             1        1            1.08724     0.697201   0.693703      0.698637   0.693656 |
# | train_model_tune_d3e99_00001   TERMINATED               10             5        1            2.1174      0.753181   0.752257      0.752773   0.751986 |
# | train_model_tune_d3e99_00002   TERMINATED               10            10        1            2.77477     0.796438   0.796278      0.79627    0.796947 |
# | train_model_tune_d3e99_00003   TERMINATED               10            20        1            2.7553      0.776081   0.775836      0.775738   0.776297 |
# | train_model_tune_d3e99_00004   TERMINATED               10            50        1            2.86843     0.791349   0.791336      0.794076   0.793573 |
# | train_model_tune_d3e99_00005   TERMINATED               10                      1            2.79809     0.763359   0.763205      0.763299   0.763914 |
# | train_model_tune_d3e99_00006   TERMINATED               50             1        1            2.41979     0.697201   0.693703      0.698637   0.693656 |
# | train_model_tune_d3e99_00007   TERMINATED               50             5        1            7.79066     0.788804   0.78814       0.788434   0.787939 |
# | train_model_tune_d3e99_00008   TERMINATED               50            10        1           11.5381      0.811705   0.811557      0.811538   0.81225  |
# | train_model_tune_d3e99_00009   TERMINATED               50            20        1           11.6028      0.801527   0.801371      0.80136    0.802048 |
# | train_model_tune_d3e99_00010   TERMINATED               50            50        1           11.2941      0.814249   0.814206      0.81478    0.815417 |
# | train_model_tune_d3e99_00011   TERMINATED               50                      1           11.5567      0.804071   0.803944      0.804012   0.804722 |
# | train_model_tune_d3e99_00012   TERMINATED              100             1        1            4.528       0.692112   0.688555      0.693405   0.688555 |
# | train_model_tune_d3e99_00013   TERMINATED              100             5        1           15.1177      0.783715   0.782905      0.783475   0.782592 |
# | train_model_tune_d3e99_00014   TERMINATED              100            10        1           22.1245      0.80916    0.808918      0.808769   0.80933  |
# | train_model_tune_d3e99_00015   TERMINATED              100            20        1           22.0612      0.804071   0.803888      0.803813   0.804475 |
# | train_model_tune_d3e99_00016   TERMINATED              100            50        1           22.2225      0.801527   0.801371      0.80136    0.802048 |
# | train_model_tune_d3e99_00017   TERMINATED              100                      1           20.8509      0.816794   0.816736      0.817153   0.817844 |
# | train_model_tune_d3e99_00018   TERMINATED              200             1        1            8.09925     0.699746   0.696442      0.701037   0.696329 |
# | train_model_tune_d3e99_00019   TERMINATED              200             5        1           27.2061      0.78117    0.780281      0.781012   0.779918 |
# | train_model_tune_d3e99_00020   TERMINATED              200            10        1           36.8023      0.816794   0.81665       0.816628   0.817351 |
# | train_model_tune_d3e99_00021   TERMINATED              200            20        1           35.8436      0.826972   0.826881      0.827036   0.8278   |
# | train_model_tune_d3e99_00022   TERMINATED              200            50        1           34.8006      0.816794   0.816698      0.816857   0.817598 |
# | train_model_tune_d3e99_00023   TERMINATED              200                      1           34.4792      0.829517   0.829357      0.829262   0.82998  |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
best_results = results.get_best_result(metric='f1', mode='max')

run_model(
    model_cls=RandomForestClassifier,
    model_kwargs=best_results.config,
    train_df=dfs_color['combined']['train'],
    test_dfs={dataset: dfs_color[dataset]['test'] for dataset in dfs_color.keys()},
    repeat=5
)
# Out:
# {'fog-detection': {'accuracy': [0.9811320754716981, 0.9811320754716981, 0.9811320754716981, 0.9811320754716981, 0.9811320754716981], 'f1': [0.9799242424242425, 0.9799242424242425, 0.9799242424242425, 0.9799242424242425, 0.9799242424242425], 'precision': [0.9850746268656716, 0.9850746268656716, 0.9850746268656716, 0.9850746268656716, 0.9850746268656716], 'recall': [0.975609756097561, 0.975609756097561, 0.975609756097561, 0.975609756097561, 0.975609756097561]}, 'foggy-cityscapes': {'accuracy': [0.7777777777777778, 0.7929292929292929, 0.7828282828282829, 0.7929292929292929, 0.8181818181818182], 'f1': [0.7732431025507549, 0.7900969618616678, 0.7780674087010921, 0.7900969618616678, 0.8154706430568499], 'precision': [0.801929688366419, 0.8096419327006039, 0.809375, 0.8096419327006039, 0.838048780487805], 'recall': [0.7777777777777778, 0.7929292929292929, 0.7828282828282829, 0.7929292929292929, 0.8181818181818182]}, 'fog-or-smog': {'accuracy': [0.9245689655172413, 0.9245689655172413, 0.9202586206896551, 0.9224137931034483, 0.9224137931034483], 'f1': [0.9245517939855143, 0.9245517939855143, 0.920249360108886, 0.9224008176159064, 0.9224008176159064], 'precision': [0.9246511714322874, 0.9246511714322874, 0.9205518907367833, 0.9225938312894835, 0.9225938312894835], 'recall': [0.9251488095238095, 0.9251488095238095, 0.9209821428571429, 0.9230654761904762, 0.9230654761904762]}, 'combined': {'accuracy': [0.89453125, 0.8984375, 0.8932291666666666, 0.8971354166666666, 0.9036458333333334], 'f1': [0.8945267794621558, 0.8984202779605375, 0.8932284425757011, 0.8971212884256363, 0.9036353771025503], 'precision': [0.8961529840862319, 0.8993865197209479, 0.8953184895196151, 0.8982081650660061, 0.9048550016291952], 'recall': [0.8966244151887717, 0.9002012838646503, 0.8955227940376456, 0.8989636601022739, 0.9055597867479055]}}
# 'fog-detection & 0.9811 ± 0.0000 & 0.9799 ± 0.0000 & 0.9851 ± 0.0000 & 0.9756 ± 0.0000 \\\\\nfoggy-cityscapes & 0.7929 ± 0.0139 & 0.7894 ± 0.0146 & 0.8137 ± 0.0125 & 0.7929 ± 0.0139 \\\\\nfog-or-smog & 0.9228 ± 0.0016 & 0.9228 ± 0.0016 & 0.9230 ± 0.0015 & 0.9235 ± 0.0016 \\\\\ncombined & 0.8974 ± 0.0036 & 0.8974 ± 0.0036 & 0.8988 ± 0.0034 & 0.8994 ± 0.0035 \\\\\n'

# %% [markdown]
# # XGBoost

# %%
tuner = tune.Tuner(
    tune.with_resources(
        tune.with_parameters(
            train_model_tune,
            model_cls=XGBClassifier,
            train_df=subsample_df(dfs_color['combined']['train'], frac=0.2),
            val_df=dfs_color['combined']['val']
        ),
        resources={"cpu": 8}
    ),
    param_space={
        "n_estimators": tune.grid_search([10, 50, 100, 200]),
        "max_depth": tune.grid_search([1, 5, 10, 20, 50, None]),

    }
)

results = tuner.fit()
# Out:
# +-------------------------------------------------------------------------+
# | Configuration for experiment     train_model_tune_2025-06-08_01-23-40   |
# +-------------------------------------------------------------------------+
# | Search algorithm                 BasicVariantGenerator                  |
# | Scheduler                        FIFOScheduler                          |
# | Number of trials                 24                                     |
# +-------------------------------------------------------------------------+
#
# View detailed results here: /root/ray_results/train_model_tune_2025-06-08_01-23-40
# To visualize your results with TensorBoard, run: `tensorboard --logdir /tmp/ray/session_2025-06-07_22-57-39_793194_4490/artifacts/2025-06-08_01-23-40/train_model_tune_2025-06-08_01-23-40/driver_artifacts`
#
# Trial status: 24 PENDING
# Current time: 2025-06-08 01:23:40. Total running time: 0s
# Logical resource usage: 0/8 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------+
# | Trial name                     status       n_estimators     max_depth |
# +------------------------------------------------------------------------+
# | train_model_tune_357bc_00000   PENDING                10             1 |
# | train_model_tune_357bc_00001   PENDING                10             5 |
# | train_model_tune_357bc_00002   PENDING                10            10 |
# | train_model_tune_357bc_00003   PENDING                10            20 |
# | train_model_tune_357bc_00004   PENDING                10            50 |
# +------------------------------------------------------------------------+
# 19 more PENDING
#
# Trial train_model_tune_357bc_00000 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_357bc_00000 config        |
# +--------------------------------------------------+
# | max_depth                                      1 |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial status: 1 RUNNING | 23 PENDING
# Current time: 2025-06-08 01:24:10. Total running time: 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------+
# | Trial name                     status       n_estimators     max_depth |
# +------------------------------------------------------------------------+
# | train_model_tune_357bc_00000   RUNNING                10             1 |
# | train_model_tune_357bc_00001   PENDING                10             5 |
# | train_model_tune_357bc_00002   PENDING                10            10 |
# | train_model_tune_357bc_00003   PENDING                10            20 |
# | train_model_tune_357bc_00004   PENDING                10            50 |
# | train_model_tune_357bc_00005   PENDING                10               |
# +------------------------------------------------------------------------+
# 18 more PENDING
#
# Trial train_model_tune_357bc_00000 completed after 1 iterations at 2025-06-08 01:24:17. Total running time: 37s
# +-------------------------------------------------------+
# | Trial train_model_tune_357bc_00000 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              32.9173 |
# | time_total_s                                  32.9173 |
# | training_iteration                                  1 |
# | accuracy                                      0.75573 |
# | f1                                             0.7533 |
# | precision                                     0.75791 |
# | recall                                        0.75269 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_357bc_00001 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_357bc_00001 config        |
# +--------------------------------------------------+
# | max_depth                                      5 |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial status: 1 TERMINATED | 1 RUNNING | 22 PENDING
# Current time: 2025-06-08 01:24:40. Total running time: 1min 0s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_357bc_00001   RUNNING                  10             5                                                                              |
# | train_model_tune_357bc_00000   TERMINATED               10             1        1            32.9173     0.755725   0.753296      0.757909   0.752687 |
# | train_model_tune_357bc_00002   PENDING                  10            10                                                                              |
# | train_model_tune_357bc_00003   PENDING                  10            20                                                                              |
# | train_model_tune_357bc_00004   PENDING                  10            50                                                                              |
# | train_model_tune_357bc_00005   PENDING                  10                                                                                            |
# | train_model_tune_357bc_00006   PENDING                  50             1                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 17 more PENDING
# Trial status: 1 TERMINATED | 1 RUNNING | 22 PENDING
# Current time: 2025-06-08 01:25:10. Total running time: 1min 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_357bc_00001   RUNNING                  10             5                                                                              |
# | train_model_tune_357bc_00000   TERMINATED               10             1        1            32.9173     0.755725   0.753296      0.757909   0.752687 |
# | train_model_tune_357bc_00002   PENDING                  10            10                                                                              |
# | train_model_tune_357bc_00003   PENDING                  10            20                                                                              |
# | train_model_tune_357bc_00004   PENDING                  10            50                                                                              |
# | train_model_tune_357bc_00005   PENDING                  10                                                                                            |
# | train_model_tune_357bc_00006   PENDING                  50             1                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 17 more PENDING
# Trial status: 1 TERMINATED | 1 RUNNING | 22 PENDING
# Current time: 2025-06-08 01:25:40. Total running time: 2min 0s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_357bc_00001   RUNNING                  10             5                                                                              |
# | train_model_tune_357bc_00000   TERMINATED               10             1        1            32.9173     0.755725   0.753296      0.757909   0.752687 |
# | train_model_tune_357bc_00002   PENDING                  10            10                                                                              |
# | train_model_tune_357bc_00003   PENDING                  10            20                                                                              |
# | train_model_tune_357bc_00004   PENDING                  10            50                                                                              |
# | train_model_tune_357bc_00005   PENDING                  10                                                                                            |
# | train_model_tune_357bc_00006   PENDING                  50             1                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 17 more PENDING
#
# Trial train_model_tune_357bc_00001 completed after 1 iterations at 2025-06-08 01:26:06. Total running time: 2min 26s
# +-------------------------------------------------------+
# | Trial train_model_tune_357bc_00001 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              105.802 |
# | time_total_s                                  105.802 |
# | training_iteration                                  1 |
# | accuracy                                      0.77608 |
# | f1                                            0.77408 |
# | precision                                     0.77815 |
# | recall                                        0.77334 |
# +-------------------------------------------------------+
#
# Trial status: 2 TERMINATED | 22 PENDING
# Current time: 2025-06-08 01:26:10. Total running time: 2min 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_357bc_00000   TERMINATED               10             1        1            32.9173     0.755725   0.753296      0.757909   0.752687 |
# | train_model_tune_357bc_00001   TERMINATED               10             5        1           105.802      0.776081   0.774079      0.778146   0.773337 |
# | train_model_tune_357bc_00002   PENDING                  10            10                                                                              |
# | train_model_tune_357bc_00003   PENDING                  10            20                                                                              |
# | train_model_tune_357bc_00004   PENDING                  10            50                                                                              |
# | train_model_tune_357bc_00005   PENDING                  10                                                                                            |
# | train_model_tune_357bc_00006   PENDING                  50             1                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 17 more PENDING
#
# Trial train_model_tune_357bc_00002 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_357bc_00002 config        |
# +--------------------------------------------------+
# | max_depth                                     10 |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial status: 2 TERMINATED | 1 RUNNING | 21 PENDING
# Current time: 2025-06-08 01:26:40. Total running time: 3min 0s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_357bc_00002   RUNNING                  10            10                                                                              |
# | train_model_tune_357bc_00000   TERMINATED               10             1        1            32.9173     0.755725   0.753296      0.757909   0.752687 |
# | train_model_tune_357bc_00001   TERMINATED               10             5        1           105.802      0.776081   0.774079      0.778146   0.773337 |
# | train_model_tune_357bc_00003   PENDING                  10            20                                                                              |
# | train_model_tune_357bc_00004   PENDING                  10            50                                                                              |
# | train_model_tune_357bc_00005   PENDING                  10                                                                                            |
# | train_model_tune_357bc_00006   PENDING                  50             1                                                                              |
# | train_model_tune_357bc_00007   PENDING                  50             5                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 16 more PENDING
# Trial status: 2 TERMINATED | 1 RUNNING | 21 PENDING
# Current time: 2025-06-08 01:27:10. Total running time: 3min 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_357bc_00002   RUNNING                  10            10                                                                              |
# | train_model_tune_357bc_00000   TERMINATED               10             1        1            32.9173     0.755725   0.753296      0.757909   0.752687 |
# | train_model_tune_357bc_00001   TERMINATED               10             5        1           105.802      0.776081   0.774079      0.778146   0.773337 |
# | train_model_tune_357bc_00003   PENDING                  10            20                                                                              |
# | train_model_tune_357bc_00004   PENDING                  10            50                                                                              |
# | train_model_tune_357bc_00005   PENDING                  10                                                                                            |
# | train_model_tune_357bc_00006   PENDING                  50             1                                                                              |
# | train_model_tune_357bc_00007   PENDING                  50             5                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 16 more PENDING
# Trial status: 2 TERMINATED | 1 RUNNING | 21 PENDING
# Current time: 2025-06-08 01:27:40. Total running time: 4min 0s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_357bc_00002   RUNNING                  10            10                                                                              |
# | train_model_tune_357bc_00000   TERMINATED               10             1        1            32.9173     0.755725   0.753296      0.757909   0.752687 |
# | train_model_tune_357bc_00001   TERMINATED               10             5        1           105.802      0.776081   0.774079      0.778146   0.773337 |
# | train_model_tune_357bc_00003   PENDING                  10            20                                                                              |
# | train_model_tune_357bc_00004   PENDING                  10            50                                                                              |
# | train_model_tune_357bc_00005   PENDING                  10                                                                                            |
# | train_model_tune_357bc_00006   PENDING                  50             1                                                                              |
# | train_model_tune_357bc_00007   PENDING                  50             5                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 16 more PENDING
# Trial status: 2 TERMINATED | 1 RUNNING | 21 PENDING
# Current time: 2025-06-08 01:28:10. Total running time: 4min 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_357bc_00002   RUNNING                  10            10                                                                              |
# | train_model_tune_357bc_00000   TERMINATED               10             1        1            32.9173     0.755725   0.753296      0.757909   0.752687 |
# | train_model_tune_357bc_00001   TERMINATED               10             5        1           105.802      0.776081   0.774079      0.778146   0.773337 |
# | train_model_tune_357bc_00003   PENDING                  10            20                                                                              |
# | train_model_tune_357bc_00004   PENDING                  10            50                                                                              |
# | train_model_tune_357bc_00005   PENDING                  10                                                                                            |
# | train_model_tune_357bc_00006   PENDING                  50             1                                                                              |
# | train_model_tune_357bc_00007   PENDING                  50             5                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 16 more PENDING
#
# Trial train_model_tune_357bc_00002 completed after 1 iterations at 2025-06-08 01:28:19. Total running time: 4min 39s
# +-------------------------------------------------------+
# | Trial train_model_tune_357bc_00002 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              128.537 |
# | time_total_s                                  128.537 |
# | training_iteration                                  1 |
# | accuracy                                      0.83715 |
# | f1                                            0.83677 |
# | precision                                     0.83677 |
# | recall                                        0.83677 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_357bc_00003 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_357bc_00003 config        |
# +--------------------------------------------------+
# | max_depth                                     20 |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial status: 3 TERMINATED | 1 RUNNING | 20 PENDING
# Current time: 2025-06-08 01:28:40. Total running time: 5min 0s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_357bc_00003   RUNNING                  10            20                                                                              |
# | train_model_tune_357bc_00000   TERMINATED               10             1        1            32.9173     0.755725   0.753296      0.757909   0.752687 |
# | train_model_tune_357bc_00001   TERMINATED               10             5        1           105.802      0.776081   0.774079      0.778146   0.773337 |
# | train_model_tune_357bc_00002   TERMINATED               10            10        1           128.537      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00004   PENDING                  10            50                                                                              |
# | train_model_tune_357bc_00005   PENDING                  10                                                                                            |
# | train_model_tune_357bc_00006   PENDING                  50             1                                                                              |
# | train_model_tune_357bc_00007   PENDING                  50             5                                                                              |
# | train_model_tune_357bc_00008   PENDING                  50            10                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 15 more PENDING
# Trial status: 3 TERMINATED | 1 RUNNING | 20 PENDING
# Current time: 2025-06-08 01:29:11. Total running time: 5min 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_357bc_00003   RUNNING                  10            20                                                                              |
# | train_model_tune_357bc_00000   TERMINATED               10             1        1            32.9173     0.755725   0.753296      0.757909   0.752687 |
# | train_model_tune_357bc_00001   TERMINATED               10             5        1           105.802      0.776081   0.774079      0.778146   0.773337 |
# | train_model_tune_357bc_00002   TERMINATED               10            10        1           128.537      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00004   PENDING                  10            50                                                                              |
# | train_model_tune_357bc_00005   PENDING                  10                                                                                            |
# | train_model_tune_357bc_00006   PENDING                  50             1                                                                              |
# | train_model_tune_357bc_00007   PENDING                  50             5                                                                              |
# | train_model_tune_357bc_00008   PENDING                  50            10                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 15 more PENDING
# Trial status: 3 TERMINATED | 1 RUNNING | 20 PENDING
# Current time: 2025-06-08 01:29:41. Total running time: 6min 0s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_357bc_00003   RUNNING                  10            20                                                                              |
# | train_model_tune_357bc_00000   TERMINATED               10             1        1            32.9173     0.755725   0.753296      0.757909   0.752687 |
# | train_model_tune_357bc_00001   TERMINATED               10             5        1           105.802      0.776081   0.774079      0.778146   0.773337 |
# | train_model_tune_357bc_00002   TERMINATED               10            10        1           128.537      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00004   PENDING                  10            50                                                                              |
# | train_model_tune_357bc_00005   PENDING                  10                                                                                            |
# | train_model_tune_357bc_00006   PENDING                  50             1                                                                              |
# | train_model_tune_357bc_00007   PENDING                  50             5                                                                              |
# | train_model_tune_357bc_00008   PENDING                  50            10                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 15 more PENDING
# Trial status: 3 TERMINATED | 1 RUNNING | 20 PENDING
# Current time: 2025-06-08 01:30:11. Total running time: 6min 30s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_357bc_00003   RUNNING                  10            20                                                                              |
# | train_model_tune_357bc_00000   TERMINATED               10             1        1            32.9173     0.755725   0.753296      0.757909   0.752687 |
# | train_model_tune_357bc_00001   TERMINATED               10             5        1           105.802      0.776081   0.774079      0.778146   0.773337 |
# | train_model_tune_357bc_00002   TERMINATED               10            10        1           128.537      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00004   PENDING                  10            50                                                                              |
# | train_model_tune_357bc_00005   PENDING                  10                                                                                            |
# | train_model_tune_357bc_00006   PENDING                  50             1                                                                              |
# | train_model_tune_357bc_00007   PENDING                  50             5                                                                              |
# | train_model_tune_357bc_00008   PENDING                  50            10                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 15 more PENDING
#
# Trial train_model_tune_357bc_00003 completed after 1 iterations at 2025-06-08 01:30:23. Total running time: 6min 43s
# +-------------------------------------------------------+
# | Trial train_model_tune_357bc_00003 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              119.063 |
# | time_total_s                                  119.063 |
# | training_iteration                                  1 |
# | accuracy                                      0.83715 |
# | f1                                            0.83677 |
# | precision                                     0.83677 |
# | recall                                        0.83677 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_357bc_00004 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_357bc_00004 config        |
# +--------------------------------------------------+
# | max_depth                                     50 |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial status: 4 TERMINATED | 1 RUNNING | 19 PENDING
# Current time: 2025-06-08 01:30:41. Total running time: 7min 1s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_357bc_00004   RUNNING                  10            50                                                                              |
# | train_model_tune_357bc_00000   TERMINATED               10             1        1            32.9173     0.755725   0.753296      0.757909   0.752687 |
# | train_model_tune_357bc_00001   TERMINATED               10             5        1           105.802      0.776081   0.774079      0.778146   0.773337 |
# | train_model_tune_357bc_00002   TERMINATED               10            10        1           128.537      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00003   TERMINATED               10            20        1           119.063      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00005   PENDING                  10                                                                                            |
# | train_model_tune_357bc_00006   PENDING                  50             1                                                                              |
# | train_model_tune_357bc_00007   PENDING                  50             5                                                                              |
# | train_model_tune_357bc_00008   PENDING                  50            10                                                                              |
# | train_model_tune_357bc_00009   PENDING                  50            20                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 14 more PENDING
# Trial status: 4 TERMINATED | 1 RUNNING | 19 PENDING
# Current time: 2025-06-08 01:31:11. Total running time: 7min 31s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_357bc_00004   RUNNING                  10            50                                                                              |
# | train_model_tune_357bc_00000   TERMINATED               10             1        1            32.9173     0.755725   0.753296      0.757909   0.752687 |
# | train_model_tune_357bc_00001   TERMINATED               10             5        1           105.802      0.776081   0.774079      0.778146   0.773337 |
# | train_model_tune_357bc_00002   TERMINATED               10            10        1           128.537      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00003   TERMINATED               10            20        1           119.063      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00005   PENDING                  10                                                                                            |
# | train_model_tune_357bc_00006   PENDING                  50             1                                                                              |
# | train_model_tune_357bc_00007   PENDING                  50             5                                                                              |
# | train_model_tune_357bc_00008   PENDING                  50            10                                                                              |
# | train_model_tune_357bc_00009   PENDING                  50            20                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 14 more PENDING
# Trial status: 4 TERMINATED | 1 RUNNING | 19 PENDING
# Current time: 2025-06-08 01:31:41. Total running time: 8min 1s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_357bc_00004   RUNNING                  10            50                                                                              |
# | train_model_tune_357bc_00000   TERMINATED               10             1        1            32.9173     0.755725   0.753296      0.757909   0.752687 |
# | train_model_tune_357bc_00001   TERMINATED               10             5        1           105.802      0.776081   0.774079      0.778146   0.773337 |
# | train_model_tune_357bc_00002   TERMINATED               10            10        1           128.537      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00003   TERMINATED               10            20        1           119.063      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00005   PENDING                  10                                                                                            |
# | train_model_tune_357bc_00006   PENDING                  50             1                                                                              |
# | train_model_tune_357bc_00007   PENDING                  50             5                                                                              |
# | train_model_tune_357bc_00008   PENDING                  50            10                                                                              |
# | train_model_tune_357bc_00009   PENDING                  50            20                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 14 more PENDING
# Trial status: 4 TERMINATED | 1 RUNNING | 19 PENDING
# Current time: 2025-06-08 01:32:11. Total running time: 8min 31s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_357bc_00004   RUNNING                  10            50                                                                              |
# | train_model_tune_357bc_00000   TERMINATED               10             1        1            32.9173     0.755725   0.753296      0.757909   0.752687 |
# | train_model_tune_357bc_00001   TERMINATED               10             5        1           105.802      0.776081   0.774079      0.778146   0.773337 |
# | train_model_tune_357bc_00002   TERMINATED               10            10        1           128.537      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00003   TERMINATED               10            20        1           119.063      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00005   PENDING                  10                                                                                            |
# | train_model_tune_357bc_00006   PENDING                  50             1                                                                              |
# | train_model_tune_357bc_00007   PENDING                  50             5                                                                              |
# | train_model_tune_357bc_00008   PENDING                  50            10                                                                              |
# | train_model_tune_357bc_00009   PENDING                  50            20                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 14 more PENDING
#
# Trial train_model_tune_357bc_00004 completed after 1 iterations at 2025-06-08 01:32:25. Total running time: 8min 45s
# +-------------------------------------------------------+
# | Trial train_model_tune_357bc_00004 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              118.458 |
# | time_total_s                                  118.458 |
# | training_iteration                                  1 |
# | accuracy                                      0.83715 |
# | f1                                            0.83677 |
# | precision                                     0.83677 |
# | recall                                        0.83677 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_357bc_00005 started with configuration:
# +--------------------------------------------------+
# | Trial train_model_tune_357bc_00005 config        |
# +--------------------------------------------------+
# | max_depth                                        |
# | n_estimators                                  10 |
# +--------------------------------------------------+
#
# Trial status: 5 TERMINATED | 1 RUNNING | 18 PENDING
# Current time: 2025-06-08 01:32:41. Total running time: 9min 1s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_357bc_00005   RUNNING                  10                                                                                            |
# | train_model_tune_357bc_00000   TERMINATED               10             1        1            32.9173     0.755725   0.753296      0.757909   0.752687 |
# | train_model_tune_357bc_00001   TERMINATED               10             5        1           105.802      0.776081   0.774079      0.778146   0.773337 |
# | train_model_tune_357bc_00002   TERMINATED               10            10        1           128.537      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00003   TERMINATED               10            20        1           119.063      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00004   TERMINATED               10            50        1           118.458      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00006   PENDING                  50             1                                                                              |
# | train_model_tune_357bc_00007   PENDING                  50             5                                                                              |
# | train_model_tune_357bc_00008   PENDING                  50            10                                                                              |
# | train_model_tune_357bc_00009   PENDING                  50            20                                                                              |
# | train_model_tune_357bc_00010   PENDING                  50            50                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 13 more PENDING
# Trial status: 5 TERMINATED | 1 RUNNING | 18 PENDING
# Current time: 2025-06-08 01:33:11. Total running time: 9min 31s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_357bc_00005   RUNNING                  10                                                                                            |
# | train_model_tune_357bc_00000   TERMINATED               10             1        1            32.9173     0.755725   0.753296      0.757909   0.752687 |
# | train_model_tune_357bc_00001   TERMINATED               10             5        1           105.802      0.776081   0.774079      0.778146   0.773337 |
# | train_model_tune_357bc_00002   TERMINATED               10            10        1           128.537      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00003   TERMINATED               10            20        1           119.063      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00004   TERMINATED               10            50        1           118.458      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00006   PENDING                  50             1                                                                              |
# | train_model_tune_357bc_00007   PENDING                  50             5                                                                              |
# | train_model_tune_357bc_00008   PENDING                  50            10                                                                              |
# | train_model_tune_357bc_00009   PENDING                  50            20                                                                              |
# | train_model_tune_357bc_00010   PENDING                  50            50                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 13 more PENDING
# Trial status: 5 TERMINATED | 1 RUNNING | 18 PENDING
# Current time: 2025-06-08 01:33:41. Total running time: 10min 1s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# ...
# 8 more TERMINATED, 5 more PENDING
#
# Trial train_model_tune_357bc_00013 completed after 1 iterations at 2025-06-08 01:59:38. Total running time: 35min 58s
# +-------------------------------------------------------+
# | Trial train_model_tune_357bc_00013 result             |
# +-------------------------------------------------------+
# | checkpoint_dir_name                                   |
# | time_this_iter_s                              261.608 |
# | time_total_s                                  261.608 |
# | training_iteration                                  1 |
# | accuracy                                       0.8117 |
# | f1                                            0.81053 |
# | precision                                      0.8128 |
# | recall                                        0.80978 |
# +-------------------------------------------------------+
#
# Trial train_model_tune_357bc_00014 started with configuration:
# +---------------------------------------------------+
# | Trial train_model_tune_357bc_00014 config         |
# +---------------------------------------------------+
# | max_depth                                      10 |
# | n_estimators                                  100 |
# +---------------------------------------------------+
#
# Trial status: 14 TERMINATED | 1 RUNNING | 9 PENDING
# Current time: 2025-06-08 01:59:43. Total running time: 36min 3s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_357bc_00014   RUNNING                 100            10                                                                              |
# | train_model_tune_357bc_00000   TERMINATED               10             1        1            32.9173     0.755725   0.753296      0.757909   0.752687 |
# | train_model_tune_357bc_00001   TERMINATED               10             5        1           105.802      0.776081   0.774079      0.778146   0.773337 |
# | train_model_tune_357bc_00002   TERMINATED               10            10        1           128.537      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00003   TERMINATED               10            20        1           119.063      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00004   TERMINATED               10            50        1           118.458      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00015   PENDING                 100            20                                                                              |
# | train_model_tune_357bc_00016   PENDING                 100            50                                                                              |
# | train_model_tune_357bc_00017   PENDING                 100                                                                                            |
# | train_model_tune_357bc_00018   PENDING                 200             1                                                                              |
# | train_model_tune_357bc_00019   PENDING                 200             5                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 9 more TERMINATED, 4 more PENDING
# Trial status: 14 TERMINATED | 1 RUNNING | 9 PENDING
# Current time: 2025-06-08 02:00:13. Total running time: 36min 33s
# Logical resource usage: 8.0/8 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                     status         n_estimators     max_depth     iter     total time (s)     accuracy         f1     precision     recall |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_model_tune_357bc_00014   RUNNING                 100            10                                                                              |
# | train_model_tune_357bc_00000   TERMINATED               10             1        1            32.9173     0.755725   0.753296      0.757909   0.752687 |
# | train_model_tune_357bc_00001   TERMINATED               10             5        1           105.802      0.776081   0.774079      0.778146   0.773337 |
# | train_model_tune_357bc_00002   TERMINATED               10            10        1           128.537      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00003   TERMINATED               10            20        1           119.063      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00004   TERMINATED               10            50        1           118.458      0.83715    0.836769      0.836769   0.836769 |
# | train_model_tune_357bc_00015   PENDING                 100            20                                                                              |
# | train_model_tune_357bc_00016   PENDING                 100            50                                                                              |
# | train_model_tune_357bc_00017   PENDING                 100                                                                                            |
# | train_model_tune_357bc_00018   PENDING                 200             1                                                                              |
# | train_model_tune_357bc_00019   PENDING                 200             5                                                                              |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------+
# 9 more TERMINATED, 4 more PENDING
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/ray/air/execution/_internal/event_manager.py in resolve_future(self, future)
#     109         try:
# --> 110             result = ray.get(future)
#     111         except Exception as e:
#
# /usr/local/lib/python3.11/dist-packages/ray/_private/auto_init_hook.py in auto_init_wrapper(*args, **kwargs)
#      20         auto_init_ray()
# ---> 21         return fn(*args, **kwargs)
#      22
#
# /usr/local/lib/python3.11/dist-packages/ray/_private/client_mode_hook.py in wrapper(*args, **kwargs)
#     102                 return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103         return func(*args, **kwargs)
#     104
#
# /usr/local/lib/python3.11/dist-packages/ray/_private/worker.py in get(object_refs, timeout)
#    2821         # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 2822         values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#    2823         for i, value in enumerate(values):
#
# /usr/local/lib/python3.11/dist-packages/ray/_private/worker.py in get_objects(self, object_refs, timeout, return_exceptions, skip_deserialization)
#     931                     else:
# --> 932                         raise value
#     933
#
# OutOfMemoryError: Task was killed due to the node running low on memory.
# Memory on the node (IP: 172.28.0.12, ID: c354743bf54d08c6312c1688b1d5b0b7057cd5bcc127a754d2b04015) where the task (actor ID: bf248437ae1d3f597f20e15901000000, name=ImplicitFunc.__init__, pid=55325, memory used=32.49GB) was running was 48.51GB / 50.99GB (0.951332), which exceeds the memory usage threshold of 0.95. Ray killed this worker (ID: e96f27866f4ed7365172dd790368947ee00f09031626ab1a330cd786) because it was the most recently scheduled task; to see more information about memory usage on this node, use `ray logs raylet.out -ip 172.28.0.12`. To see the logs of the worker, use `ray logs worker-e96f27866f4ed7365172dd790368947ee00f09031626ab1a330cd786*out -ip 172.28.0.12. Top 10 memory users:
# PID	MEM(GB)	COMMAND
# 55325	32.49	ray::ImplicitFunc.train
# 4490	4.33	/usr/bin/python3 -m colab_kernel_launcher -f /root/.local/share/jupyter/runtime/kernel-792d03f0-cdd5...
# 103	0.10	/usr/bin/python3 /usr/local/bin/jupyter-notebook --debug --transport="ipc" --ip=172.28.0.12 --Notebo...
# 4889	0.09	/opt/google/drive/drive --features=crash_throttle_percentage:100,fuse_max_background:1000,max_read_q...
# 7	0.07	/tools/node/bin/node /datalab/web/app.js
# 6690	0.06	/usr/bin/python3 /usr/local/lib/python3.11/dist-packages/ray/dashboard/dashboard.py --host=127.0.0.1...
# 6640	0.06	/usr/local/lib/python3.11/dist-packages/ray/core/src/ray/gcs/gcs_server --log_dir=/tmp/ray/session_2...
# 6785	0.06	/usr/bin/python3 -u /usr/local/lib/python3.11/dist-packages/ray/dashboard/agent.py --node-ip-address...
# 6689	0.05	/usr/bin/python3 -u /usr/local/lib/python3.11/dist-packages/ray/autoscaler/_private/monitor.py --log...
# 6748	0.05	/usr/bin/python3 -u /usr/local/lib/python3.11/dist-packages/ray/_private/log_monitor.py --session-di...
# Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. Set max_restarts and max_task_retries to enable retry when the task crashes due to OOM. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-23-255859316c9d> in <cell line: 0>()
#      16 )
#      17
# ---> 18 results = tuner.fit()
#
# /usr/local/lib/python3.11/dist-packages/ray/tune/tuner.py in fit(self)
#     343
#     344         if not self._is_ray_client:
# --> 345             return self._local_tuner.fit()
#     346         else:
#     347             (
#
# /usr/local/lib/python3.11/dist-packages/ray/tune/impl/tuner_internal.py in fit(self)
#     504         param_space = copy.deepcopy(self.param_space)
#     505         if not self._is_restored:
# --> 506             analysis = self._fit_internal(trainable, param_space)
#     507         else:
#     508             analysis = self._fit_resume(trainable, param_space)
#
# /usr/local/lib/python3.11/dist-packages/ray/tune/impl/tuner_internal.py in _fit_internal(self, trainable, param_space)
#     620             **self._tuner_kwargs,
#     621         }
# --> 622         analysis = run(
#     623             **args,
#     624         )
#
# /usr/local/lib/python3.11/dist-packages/ray/tune/tune.py in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, storage_path, storage_filesystem, search_alg, scheduler, checkpoint_config, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, resume, resume_config, reuse_actors, raise_on_failed_trial, callbacks, max_concurrent_trials, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, chdir_to_trial_dir, local_dir, _remote, _remote_string_queue, _entrypoint)
#     992     try:
#     993         while not runner.is_finished() and not experiment_interrupted_event.is_set():
# --> 994             runner.step()
#     995             if has_verbosity(Verbosity.V1_EXPERIMENT):
#     996                 _report_progress(runner, progress_reporter)
#
# /usr/local/lib/python3.11/dist-packages/ray/tune/execution/tune_controller.py in step(self)
#     683
#     684         # Handle one event
# --> 685         if not self._actor_manager.next(timeout=0.1):
#     686             # If there are no actors running, warn about potentially
#     687             # insufficient resources
#
# /usr/local/lib/python3.11/dist-packages/ray/air/execution/_internal/actor_manager.py in next(self, timeout)
#     221             self._actor_state_events.resolve_future(future)
#     222         elif future in actor_task_futures:
# --> 223             self._actor_task_events.resolve_future(future)
#     224         else:
#     225             self._handle_ready_resource_future()
#
# /usr/local/lib/python3.11/dist-packages/ray/air/execution/_internal/event_manager.py in resolve_future(self, future)
#     111         except Exception as e:
#     112             if on_error:
# --> 113                 on_error(e)
#     114             else:
#     115                 raise e
#
# /usr/local/lib/python3.11/dist-packages/ray/air/execution/_internal/actor_manager.py in on_error(exception)
#     769
#     770         def on_error(exception: Exception):
# --> 771             self._actor_task_failed(
#     772                 tracked_actor_task=tracked_actor_task, exception=exception
#     773             )
#
# /usr/local/lib/python3.11/dist-packages/ray/air/execution/_internal/actor_manager.py in _actor_task_failed(self, tracked_actor_task, exception)
#     288                 tracked_actor_task._on_error(tracked_actor, exception)
#     289         else:
# --> 290             raise RuntimeError(
#     291                 f"Caught unexpected exception: {exception}"
#     292             ) from exception
#
# RuntimeError: Caught unexpected exception: Task was killed due to the node running low on memory.
# Memory on the node (IP: 172.28.0.12, ID: c354743bf54d08c6312c1688b1d5b0b7057cd5bcc127a754d2b04015) where the task (actor ID: bf248437ae1d3f597f20e15901000000, name=ImplicitFunc.__init__, pid=55325, memory used=32.49GB) was running was 48.51GB / 50.99GB (0.951332), which exceeds the memory usage threshold of 0.95. Ray killed this worker (ID: e96f27866f4ed7365172dd790368947ee00f09031626ab1a330cd786) because it was the most recently scheduled task; to see more information about memory usage on this node, use `ray logs raylet.out -ip 172.28.0.12`. To see the logs of the worker, use `ray logs worker-e96f27866f4ed7365172dd790368947ee00f09031626ab1a330cd786*out -ip 172.28.0.12. Top 10 memory users:
# PID	MEM(GB)	COMMAND
# 55325	32.49	ray::ImplicitFunc.train
# 4490	4.33	/usr/bin/python3 -m colab_kernel_launcher -f /root/.local/share/jupyter/runtime/kernel-792d03f0-cdd5...
# 103	0.10	/usr/bin/python3 /usr/local/bin/jupyter-notebook --debug --transport="ipc" --ip=172.28.0.12 --Notebo...
# 4889	0.09	/opt/google/drive/drive --features=crash_throttle_percentage:100,fuse_max_background:1000,max_read_q...
# 7	0.07	/tools/node/bin/node /datalab/web/app.js
# 6690	0.06	/usr/bin/python3 /usr/local/lib/python3.11/dist-packages/ray/dashboard/dashboard.py --host=127.0.0.1...
# 6640	0.06	/usr/local/lib/python3.11/dist-packages/ray/core/src/ray/gcs/gcs_server --log_dir=/tmp/ray/session_2...
# 6785	0.06	/usr/bin/python3 -u /usr/local/lib/python3.11/dist-packages/ray/dashboard/agent.py --node-ip-address...
# 6689	0.05	/usr/bin/python3 -u /usr/local/lib/python3.11/dist-packages/ray/autoscaler/_private/monitor.py --log...
# 6748	0.05	/usr/bin/python3 -u /usr/local/lib/python3.11/dist-packages/ray/_private/log_monitor.py --session-di...
# Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. Set max_restarts and max_task_retries to enable retry when the task crashes due to OOM. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.

# %%
# best_results = results.get_best_result(metric='f1', mode='max')

run_model(
    model_cls=XGBClassifier,
    # model_kwargs=best_results.config,
    model_kwargs={
        "n_estimators": 50,
        "max_depth": 5
    },
    train_df=dfs_color['combined']['train'],
    test_dfs={dataset: dfs_color[dataset]['test'] for dataset in dfs_color.keys()},
    repeat=5
)
# Out:
# {'fog-or-smog': {'accuracy': [0.9137931034482759, 0.9137931034482759, 0.9137931034482759, 0.9137931034482759, 0.9137931034482759], 'f1': [0.9136631747390358, 0.9136631747390358, 0.9136631747390358, 0.9136631747390358, 0.9136631747390358], 'precision': [0.9138187774551411, 0.9138187774551411, 0.9138187774551411, 0.9138187774551411, 0.9138187774551411], 'recall': [0.9135416666666667, 0.9135416666666667, 0.9135416666666667, 0.9135416666666667, 0.9135416666666667]}, 'fog-detection': {'accuracy': [0.9716981132075472, 0.9716981132075472, 0.9716981132075472, 0.9716981132075472, 0.9716981132075472], 'f1': [0.9697344627391262, 0.9697344627391262, 0.9697344627391262, 0.9697344627391262, 0.9697344627391262], 'precision': [0.9779411764705883, 0.9779411764705883, 0.9779411764705883, 0.9779411764705883, 0.9779411764705883], 'recall': [0.9634146341463414, 0.9634146341463414, 0.9634146341463414, 0.9634146341463414, 0.9634146341463414]}, 'foggy-cityscapes': {'accuracy': [0.7828282828282829, 0.7828282828282829, 0.7828282828282829, 0.7828282828282829, 0.7828282828282829], 'f1': [0.7808099271425997, 0.7808099271425997, 0.7808099271425997, 0.7808099271425997, 0.7808099271425997], 'precision': [0.7936440677966101, 0.7936440677966101, 0.7936440677966101, 0.7936440677966101, 0.7936440677966101], 'recall': [0.7828282828282829, 0.7828282828282829, 0.7828282828282829, 0.7828282828282829, 0.7828282828282829]}, 'combined': {'accuracy': [0.8880208333333334, 0.8880208333333334, 0.8880208333333334, 0.8880208333333334, 0.8880208333333334], 'f1': [0.8878923462355809, 0.8878923462355809, 0.8878923462355809, 0.8878923462355809, 0.8878923462355809], 'precision': [0.8877085877085877, 0.8877085877085877, 0.8877085877085877, 0.8877085877085877, 0.8877085877085877], 'recall': [0.8886682624306387, 0.8886682624306387, 0.8886682624306387, 0.8886682624306387, 0.8886682624306387]}}
# 'fog-or-smog & 0.9138 ± 0.0000 & 0.9137 ± 0.0000 & 0.9138 ± 0.0000 & 0.9135 ± 0.0000 \\\\\nfog-detection & 0.9717 ± 0.0000 & 0.9697 ± 0.0000 & 0.9779 ± 0.0000 & 0.9634 ± 0.0000 \\\\\nfoggy-cityscapes & 0.7828 ± 0.0000 & 0.7808 ± 0.0000 & 0.7936 ± 0.0000 & 0.7828 ± 0.0000 \\\\\ncombined & 0.8880 ± 0.0000 & 0.8879 ± 0.0000 & 0.8877 ± 0.0000 & 0.8887 ± 0.0000 \\\\\n'

# %% [markdown]
# ## Not Deep models

# %%
run_model(
    model_cls=LinearSVC,
    model_kwargs={},
    train_df=train_df,
    val_df=val_df,
    test_df=test_df,
    repeat=1
)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model - LinearSVC
# 	Train metrics:
# 		Accuracy: 0.9981
# 		F1: 0.9981
# 		Precision: 0.9982
# 		Recall: 0.9981
# 	Validation metrics:
# 		Accuracy: 0.7888
# 		F1: 0.7797
# 		Precision: 0.8215
# 		Recall: 0.7808
# 'combined & 0.8060 ± 0.0000 & 0.7988 ± 0.0000 & 0.8328 ± 0.0000 & 0.7983 ± 0.0000 \\\\\n'

# %%
run_model(
    model_cls=LinearSVC,
    model_kwargs={},
    train_df=train_df,
    val_df=val_df,
    test_df=test_df,
    repeat=5
)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model - LinearSVC
# 	Train metrics:
# 		Accuracy: 0.9989
# 		F1: 0.9989
# 		Precision: 0.9989
# 		Recall: 0.9989
# 	Validation metrics:
# 		Accuracy: 0.7939
# 		F1: 0.7859
# 		Precision: 0.8227
# 		Recall: 0.7864
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model - LinearSVC
# 	Train metrics:
# 		Accuracy: 0.9993
# 		F1: 0.9993
# 		Precision: 0.9993
# 		Recall: 0.9992
# 	Validation metrics:
# 		Accuracy: 0.7888
# 		F1: 0.7801
# 		Precision: 0.8192
# 		Recall: 0.7810
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model - LinearSVC
# 	Train metrics:
# 		Accuracy: 0.9967
# 		F1: 0.9967
# 		Precision: 0.9966
# 		Recall: 0.9968
# 	Validation metrics:
# 		Accuracy: 0.7939
# 		F1: 0.7883
# 		Precision: 0.8111
# 		Recall: 0.7879
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model - LinearSVC
# 	Train metrics:
# 		Accuracy: 0.9981
# 		F1: 0.9981
# 		Precision: 0.9981
# 		Recall: 0.9982
# 	Validation metrics:
# 		Accuracy: 0.7964
# 		F1: 0.7907
# 		Precision: 0.8147
# 		Recall: 0.7903
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Model - LinearSVC
# 	Train metrics:
# 		Accuracy: 0.9981
# 		F1: 0.9981
# 		Precision: 0.9982
# 		Recall: 0.9981
# 	Validation metrics:
# 		Accuracy: 0.7913
# 		F1: 0.7843
# 		Precision: 0.8146
# 		Recall: 0.7844
# 'combined & 0.8128 ± 0.0036 & 0.8071 ± 0.0042 & 0.8333 ± 0.0018 & 0.8060 ± 0.0040 \\\\\n'

# %%
run_model(
    model_cls=RandomForestClassifier,
    model_kwargs={},
    train_df=train_df,
    val_df=val_df,
    test_df=test_df,
    repeat=1
)
# Out:
# Model - RandomForestClassifier
# 	Train metrics:
# 		Accuracy: 1.0000
# 		F1: 1.0000
# 		Precision: 1.0000
# 		Recall: 1.0000
# 	Validation metrics:
# 		Accuracy: 0.9288
# 		F1: 0.9287
# 		Precision: 0.9286
# 		Recall: 0.9296
# 'combined & 0.9128 ± 0.0000 & 0.9127 ± 0.0000 & 0.9136 ± 0.0000 & 0.9145 ± 0.0000 \\\\\n'

# %%
run_model(
    model_cls=RandomForestClassifier,
    model_kwargs={},
    train_df=train_df,
    val_df=val_df,
    test_df=test_df,
    repeat=5
)
# Out:
# Model - RandomForestClassifier
# 	Train metrics:
# 		Accuracy: 1.0000
# 		F1: 1.0000
# 		Precision: 1.0000
# 		Recall: 1.0000
# 	Validation metrics:
# 		Accuracy: 0.9237
# 		F1: 0.9236
# 		Precision: 0.9235
# 		Recall: 0.9245
# Model - RandomForestClassifier
# 	Train metrics:
# 		Accuracy: 1.0000
# 		F1: 1.0000
# 		Precision: 1.0000
# 		Recall: 1.0000
# 	Validation metrics:
# 		Accuracy: 0.9186
# 		F1: 0.9185
# 		Precision: 0.9184
# 		Recall: 0.9194
# Model - RandomForestClassifier
# 	Train metrics:
# 		Accuracy: 1.0000
# 		F1: 1.0000
# 		Precision: 1.0000
# 		Recall: 1.0000
# 	Validation metrics:
# 		Accuracy: 0.9186
# 		F1: 0.9185
# 		Precision: 0.9182
# 		Recall: 0.9189
# Model - RandomForestClassifier
# 	Train metrics:
# 		Accuracy: 1.0000
# 		F1: 1.0000
# 		Precision: 1.0000
# 		Recall: 1.0000
# 	Validation metrics:
# 		Accuracy: 0.9237
# 		F1: 0.9236
# 		Precision: 0.9234
# 		Recall: 0.9242
# Model - RandomForestClassifier
# 	Train metrics:
# 		Accuracy: 1.0000
# 		F1: 1.0000
# 		Precision: 1.0000
# 		Recall: 1.0000
# 	Validation metrics:
# 		Accuracy: 0.9211
# 		F1: 0.9210
# 		Precision: 0.9208
# 		Recall: 0.9213
# 'combined & 0.9193 ± 0.0044 & 0.9193 ± 0.0044 & 0.9201 ± 0.0042 & 0.9210 ± 0.0042 \\\\\n'

# %%
run_model(
    model_cls=XGBClassifier,
    model_kwargs={},
    train_df=train_df,
    val_df=val_df,
    test_df=test_df,
    repeat=1
)
# Out:
# Model - XGBClassifier
# 	Train metrics:
# 		Accuracy: 1.0000
# 		F1: 1.0000
# 		Precision: 1.0000
# 		Recall: 1.0000
# 	Validation metrics:
# 		Accuracy: 0.9389
# 		F1: 0.9388
# 		Precision: 0.9386
# 		Recall: 0.9390
# 'combined & 0.9284 ± 0.0000 & 0.9282 ± 0.0000 & 0.9281 ± 0.0000 & 0.9283 ± 0.0000 \\\\\n'

# %%
run_model(
    model_cls=XGBClassifier,
    model_kwargs={},
    train_df=train_df,
    val_df=val_df,
    test_df=test_df,
    repeat=5
)
# Out:
# Model - XGBClassifier
# 	Train metrics:
# 		Accuracy: 1.0000
# 		F1: 1.0000
# 		Precision: 1.0000
# 		Recall: 1.0000
# 	Validation metrics:
# 		Accuracy: 0.9389
# 		F1: 0.9388
# 		Precision: 0.9386
# 		Recall: 0.9390
# Model - XGBClassifier
# 	Train metrics:
# 		Accuracy: 1.0000
# 		F1: 1.0000
# 		Precision: 1.0000
# 		Recall: 1.0000
# 	Validation metrics:
# 		Accuracy: 0.9389
# 		F1: 0.9388
# 		Precision: 0.9386
# 		Recall: 0.9390
